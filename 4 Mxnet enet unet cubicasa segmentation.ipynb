# %% [markdown]
# # Cubicasa MXNet Segmentation
#
# ## Contents
#
# 1. [Background](#Background)
# 1. [Exploratory Data Analyis & Pre-processing](#Exploratory-Data-Analysis-&-Pre-processing)
# 1. [Train Models on Sagemaker](#Train-Models-on-SageMaker)
# 1. [Inference Endpoints](#Inference-Endpoints)
# 1. [Model Evaluation](#Model-Evaluation)
# 1. [Extensions](#Extensions)
#
# ## Background
#
# This notebook shows how to apply image segmentation algorithms to medical imaging use-cases in a simple, streamlined way using Amazon SageMaker. Specifically, we'll be using Apache MXNet to train a convolutional neural network for semantic segmentation on SageMaker using the "Bring Your Own Script" paradigm. Put simply, the goal of semantic segmentation is to make classifications on an image at the pixel-level, producing a classification "mask." We will train two networks, U-Net and ENet. We'll show how to deploy these models to inference endpoints, both in the cloud on Amazon SageMaker and at the edge using AWS GreenGrass.
#
#
# ### CNN Architectures
#
# In this notebook, we apply two models to the task of brain tissue segmentation:
# * **U-Net**: Introduced in the paper [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/abs/1505.04597), this network was originally used for medical-imaging use-cases but has since proven to be reliable in generic segmentation domains. Due to it's architectural and conceptual simplicity, its often used as a baseline.
# * **ENet**: Introduced in the paper [ENet: A Deep Neural Network Architecture for Real-Time Semantic Segmentation](https://arxiv.org/abs/1606.02147), ENet is designed to be low-latency and to operate in environments with low compute capacity (e.g. edge devices). Compared to existing architectures, ENet optimizes for processing time over accuracy.
#
# ### Dataset
#
# In this notebook, we'll be using Brain MRI data from the [Open Access Series of Imaging Studies (OASIS)](http://www.oasis-brains.org/). This project offers a wealth of neuroimaging datasets; we'll be looking at a small subset of cross-sectional brain MRIs.
#
# **Note:** You need to request access on the OASIS site to get the data. In this tutorial, I'll be using the <tt>disc1.tar.gz</tt> file from the [OASIS-1](http://www.oasis-brains.org/#data) data set.
#
# ## Exploratory Data Analysis & Pre-processing
#
# In this section, we'll visualize the data and pre-process it for training a segmentation network. Once completed, we'll put the pre-processed data on S3 for SageMaker to use during model training.
#
# ### Setup
#
# We'll start by importing the libraries necessary to perform the data visualization and pre-processing.

# %%
# !conda install scikit-learn --yes

# %%
# !pip install --upgrade fastai

# %%
# %%time
import sagemaker
from sagemaker import get_execution_role

role = get_execution_role()
print(role)
sess = sagemaker.Session()
# Out:
# arn:aws:iam::308537982265:role/service-role/AmazonSageMaker-ExecutionRole-20200212T095321
# CPU times: user 400 ms, sys: 13.1 ms, total: 413 ms
# Wall time: 632 ms

# %%
bucket = sess.default_bucket()  
bucket_prefix = 'eunet-semantic-segmentation-cubicasa5k'
DATA_DIR = './data/sagemaker'

print(bucket)
# Out:
# sagemaker-us-east-2-308537982265

# %%
import numpy as np
from PIL import Image
import boto3
import os
from glob import glob
import imageio
from sklearn.model_selection import train_test_split
import time
import urllib
import tarfile
import shutil
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Download & Extract
# Next, we're going to download the compressed data file locally and extract it to our data directory. I've put the <tt>disc1.tar.gx</tt> file in S3 and will download it from there.
#
# I've left the data directory up to you, because depending on your instance type you may or may not have the disk space to download and extract this data set. Some options:
# * Download data to the shared memory at <tt>/dev/shm</tt> if you have enough storage capacity there. Data saved here is not persistent, but we're only pre-processing and putting data on S3.
# * [Mount an Elastic File System to this instance.](https://aws.amazon.com/blogs/machine-learning/mount-an-efs-file-system-to-an-amazon-sagemaker-notebook-with-lifecycle-configurations/) This is useful if you want your data to persist in a file system accessible by your instance.

# %%
# !rm -rf {DATA_DIR}/{bucket_prefix}/

# %%
def create_dir_if_not_exist(d):
    if not os.path.exists(d):
        os.mkdir(d)
create_dir_if_not_exist(os.path.join(DATA_DIR, bucket_prefix))

# %%
#if you lost your data from step 1
#!aws s3 cp --quiet --recursive s3://{bucket}/floorplans_cubicasa5k/ {DATA_DIR}/{bucket_prefix}/

# %% [markdown]
# ### Visualization

# %%
import matplotlib.image as mpimg
img=mpimg.imread(os.path.join(DATA_DIR,'images','1.jpg')) 

plt.figure(figsize=(12, 12))
imgplot = plt.imshow(img)

# %% [markdown]
# In order to train a segmentation network, we need ground-truth segmentation masks for the tissue. Fortunately, the data set comes with such masks hand-annotated by medical professionals:

# %%
img=mpimg.imread(os.path.join(DATA_DIR,'masks','1.png')) 
plt.figure(figsize=(12, 12))
plt.title('Ground Truth')
imgplot = plt.imshow(img)

# %% [markdown]
# ### Pre-processing
#
# Now that we've seen the data, we need to pre-process it to train our network on it.

# %%
import os
processed_data_dir = os.path.join(DATA_DIR, bucket_prefix, 'data')
train_dir = os.path.join(processed_data_dir, 'train')
validation_dir = os.path.join(processed_data_dir, 'validation')
img_dir = os.path.join(processed_data_dir, 'images')
mask_dir = os.path.join(processed_data_dir, 'masks')


create_dir_if_not_exist(processed_data_dir)
create_dir_if_not_exist(train_dir)
create_dir_if_not_exist(validation_dir)
create_dir_if_not_exist(img_dir)
create_dir_if_not_exist(mask_dir)

# %%
import shutil
from PIL import Image
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai.vision import *
from fastai.callbacks.hooks import *
import PIL.Image as PilImage

def getClassValues(label_names):

    containedValues = set([])

    for i in range(len(label_names)):
        tmp = open_mask(label_names[i])
        tmp = tmp.data.numpy().flatten()
        tmp = set(tmp)
        containedValues = containedValues.union(tmp)
    
    return list(containedValues)

def replaceMaskValuesFromZeroToN(mask, 
                                 containedValues):

    numberOfClasses = len(containedValues)
    #print("numberOfClasses" + str(numberOfClasses))
    newMask = np.zeros(mask.shape)

    for i in range(numberOfClasses):
        if(i==1): newMask[mask == containedValues[i]] = i
    
    return newMask

def convertMaskToPilAndSave(mask, 
                            saveTo):

    imageSize = mask.squeeze().shape

    im = PilImage.new('L',(imageSize[1],imageSize[0]))
    im.putdata(mask.astype('uint8').ravel())
    im = im.resize((208,176), resample=0)
    im.save(saveTo)

def convertMasksToGrayscaleZeroToN(pathToLabels,
                                   saveToPath):

    label_names = get_image_files(pathToLabels)
    containedValues = getClassValues(label_names)
    print("containtedValued")
    print(containedValues)

    for currentFile in label_names:
        currentMask = open_mask(currentFile).data.numpy()
        convertedMask = replaceMaskValuesFromZeroToN(currentMask, containedValues)
        new_fname = os.path.basename(currentFile.name).split('.')[0]
        new_fname = new_fname + "_mask.png"
        convertMaskToPilAndSave(convertedMask, saveToPath +"/" + new_fname)
    
    print('Conversion finished!')
    
def process_files(files, target_dir,mask=False):
    for f in files:
        img = PIL.Image.open(f).convert("L")
        img = img.resize((208,176), resample=0)
        npimg = np.array(img)
        new_fname = os.path.basename(f).split('.')[0]
        new_fname = new_fname + ".png" 
        imageio.imsave(os.path.join(target_dir, new_fname), npimg.astype(np.uint8))

    return

images = glob(os.path.join(DATA_DIR,'images','*.jpg'))
process_files(images, img_dir) 
convertMasksToGrayscaleZeroToN(os.path.join(DATA_DIR,'masks'),mask_dir)
# Out:
# containtedValued
# [0, 255]
# Conversion finished!

# %% [markdown]
# ### Sanity check images

# %%
import os
images = glob(os.path.join(img_dir,'*.png'))
for i in images:
    #print(i)
    im1 = PIL.Image.open(i)
    width1, height1 = im1.size
    im2 = PIL.Image.open(i.replace('images', 'masks').replace('.png', '_mask.png'))
    width2, height2 = im2.size
    if(width1!=width2 or height1!=height2): 
        print('skipping training image annotation missmatch ' + 'w1:' + str(width1) +  'w2:' + str(width2) +' h1:' + str(height1) + 'h2:' + str(height2))
        os.remove(i)
        os.remove(i.replace('images', 'masks').replace('.png', '_mask.png') )

images = glob(os.path.join(img_dir,'*.png'))
masks = glob(os.path.join(mask_dir,'*.png'))

images.sort()
print(len(images))
print(len(masks))

masks.sort()
#amazon-sagemaker-brain-segmentation/data/cubicasa5k/data/images/268.png
train_images, validation_images, train_masks, validation_masks = train_test_split(
images, masks, test_size=0.2, random_state=1984)
# Out:
# 400
# 400

# %% [markdown]
# Next, we're going to load each image and mask slice into memory, pre-process them, and save them to disk as individual image files into respective training and validation directories.

# %% [markdown]
# In order to pre-process the MRI images, we need to convert them from their native format to arrays that we can save as png images.
#
# The raw MRI arrays have values that represent radiological intensities. These have a far wider range than pixel intensities, and are loaded into memory as uint16. Upon saving the slices as png's, the data is scaled to fall on the \[0,255\] range of uint8.
#
# **Note**: This scaling can result in differences between tissue pixel distributions from image to image, but this doesn't prove to be a problem.

# %%
for f in train_images:
    fname = os.path.basename(f)
    shutil.copy(f, os.path.join(train_dir, fname))
    fname = fname.replace(".png","_mask.png")
    shutil.copy(f.replace("images","masks").replace(".png","_mask.png"), os.path.join(train_dir, fname))
for f in validation_images:
    fname = os.path.basename(f)
    shutil.copy(f, os.path.join(validation_dir, fname))
    fname = fname.replace(".png","_mask.png")
    shutil.copy(f.replace("images","masks").replace(".png","_mask.png"), os.path.join(validation_dir, fname))

# %% [markdown]
# For the masks, we need to save the raw masks as images with exactly one pixel per tissue class. The pixel values of the raw images are not exact, and so each raw mask's pixel values are mapped to a specific integer.

# %% [markdown]
# Note that in both steps, we saved the files under a specific naming convention. This is so the I/O iterators we'll use to load the data know how to pair the images and masks.
#
# ### Sample, Distributed Sets
#
# Now that we've pre-processed our data, we're going to make two additional data sets from this:
# * Sample data for testing our algorithm locally
# * 50-50 split of the training data for distributed training
#
# To do this, we'll grab all image, mask pairs.

# %%
train_pairs = [(img, img.split('.')[0]+'_mask.png')
               for img in os.listdir(train_dir) if 'mask' not in img]
validation_pairs = [(img, img.split('.')[0]+'_mask.png')
                    for img in os.listdir(validation_dir) if 'mask' not in img]

# %% [markdown]
# We'll sample 20% of the training and validation data.

# %%
sample_train_indices = np.random.choice(range(len(train_pairs)), size=10, replace=False)
sample_validation_indices = np.random.choice(range(len(validation_pairs)), size=10, replace=False)
sample_train_pairs = np.array(train_pairs)[sample_train_indices]
sample_validation_pairs = np.array(validation_pairs)[sample_validation_indices]

# %% [markdown]
# And save to sample directories:

# %%
sample_train_dir = os.path.join(processed_data_dir, 'sample-train')
sample_validation_dir = os.path.join(processed_data_dir, 'sample-validation')

create_dir_if_not_exist(sample_train_dir)
create_dir_if_not_exist(sample_validation_dir)

for f in sample_train_pairs.flatten():
    shutil.copy(os.path.join(train_dir, f), os.path.join(sample_train_dir, f))
for f in sample_validation_pairs.flatten():
    shutil.copy(os.path.join(validation_dir, f),
                os.path.join(sample_validation_dir, f))

# %% [markdown]
# Next, we'll split the training data in two, which we'll use in a distributed training example later.

# %%
distributed_train_indices = np.random.choice(range(len(train_pairs)), size=int(0.5*len(train_pairs)), replace=False)

dist_train_one_pairs = np.array(train_pairs)[distributed_train_indices]
dist_train_two_pairs = np.array(train_pairs)[[i for i in range(len(train_pairs))\
                                              if i not in distributed_train_indices]]

dist_dir = os.path.join(processed_data_dir, 'distributed-training')
dist_train_one_dir = os.path.join(dist_dir, 'dist-train-one')
dist_train_two_dir = os.path.join(dist_dir, 'dist-train-two')

create_dir_if_not_exist(dist_dir)
create_dir_if_not_exist(dist_train_one_dir)
create_dir_if_not_exist(dist_train_two_dir)

for f in dist_train_one_pairs.flatten():
    if(f != ".ipynb_checkpoints"):
        shutil.copy(os.path.join(train_dir, f),
                os.path.join(dist_train_one_dir, f))
for f in dist_train_two_pairs.flatten():
    if(f != ".ipynb_checkpoints"):
        shutil.copy(os.path.join(train_dir, f),
                os.path.join(dist_train_two_dir, f))

# %% [markdown]
# Now that we've generated the data splits we need, let's bundle and compress the data:

# %%
tar_gz_dir = os.path.join(data_dir, 'tar_gz')
tar_gz_train_dir = os.path.join(tar_gz_dir, "train")
tar_gz_validation_dir = os.path.join(tar_gz_dir, "validation")
tar_gz_sample_train_dir = os.path.join(tar_gz_dir, "sample-train")
tar_gz_sample_validation_dir = os.path.join(tar_gz_dir, "sample-validation")
tar_gz_dist_dir = os.path.join(tar_gz_dir, 'dist')

create_dir_if_not_exist(tar_gz_dir)
create_dir_if_not_exist(tar_gz_train_dir)
create_dir_if_not_exist(tar_gz_validation_dir)
create_dir_if_not_exist(tar_gz_sample_train_dir)
create_dir_if_not_exist(tar_gz_sample_validation_dir)
create_dir_if_not_exist(tar_gz_dist_dir)

with tarfile.open(os.path.join(tar_gz_train_dir, "train.tar.gz"), "w:gz") as tar:
    tar.add(train_dir, arcname='')
with tarfile.open(os.path.join(tar_gz_validation_dir, "validation.tar.gz"), "w:gz") as tar:
    tar.add(validation_dir, arcname='')
with tarfile.open(os.path.join(tar_gz_sample_train_dir, "sample-train.tar.gz"), "w:gz") as tar:
    tar.add(sample_train_dir, arcname='')
with tarfile.open(os.path.join(tar_gz_sample_validation_dir, "sample-validation.tar.gz"), "w:gz") as tar:
    tar.add(sample_validation_dir, arcname='')
with tarfile.open(os.path.join(tar_gz_dist_dir, "dist-train-one.tar.gz"), "w:gz") as tar:
    tar.add(dist_train_one_dir, arcname='')
with tarfile.open(os.path.join(tar_gz_dist_dir, "dist-train-two.tar.gz"), "w:gz") as tar:
    tar.add(dist_train_two_dir, arcname='')

# %% [markdown]
# Now we're ready to put this data on S3 and start training our models.
#
# ## Train Models on SageMaker
#
# ### Setup
#
# We'll begin by importing the SageMaker python SDK. We're going to define:
# * Session object that provides convenience methods within the context of SageMaker and our own account.
# * SageMaker role ARN used to delegate permissions to the training and hosting service. We need this so these services can access the S3 buckets where your data and model is stored.
#
# We'll also import the sagemaker <tt>MXNet</tt> estimator object. This object references default containers that AWS provides, and users provide only entry points and supporting code. This is known as "Bring Your Own Script."

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.mxnet import MXNet

sagemaker_session = sagemaker.Session()
role = get_execution_role()

# %% [markdown]
# ### s3 data
#
# Next, we're going to upload the pre-processed data to S3 using the <tt>upload_data</tt> method to put the objects in a default SageMaker bucket. We're going to pass the parent directory containing the compressed files to the method, which syncs the child tree to the bucket.

# %%
data_bucket=sagemaker_session.default_bucket()

# %%
# !aws s3 rm --quiet --recursive s3://{data_bucket}/{bucket_prefix}/

# %%
data_bucket = sagemaker_session.upload_data(path=tar_gz_dir, key_prefix=bucket_prefix)

# %% [markdown]
# ### Entry Point
#
# As mentioned, the <tt>MXNet</tt> estimator uses a default MXNet container and the user simply provides the code that defines the training.
#
# The script we'll be passing as an entry point to the estimator is <tt>brain_segmentation.py</tt>:

# %%
# !cat source_dir/floorplan_segmentation.py
# Out:
# import os
# import tarfile
# import mxnet as mx
# import numpy as np
# from iterator import DataLoaderIter
# from losses_and_metrics import avg_dice_coef_metric, avg_dice_coef_metric_floorplan
# from models import build_unet, build_enet
# import logging
#
# logging.getLogger().setLevel(logging.DEBUG)
#
# ###############################
# ###     Training Loop       ###
# ###############################
#
# def train(current_host, channel_input_dirs, hyperparameters, hosts, num_cpus, num_gpus):
#
#     logging.info(mx.__version__)
#
#     # Set context for compute based on instance environment
#     if num_gpus > 0:
#         ctx = [mx.gpu(i) for i in range(num_gpus)]
#     else:
#         ctx = mx.cpu()
#
#     # Set location of key-value store based on training config.
#     if len(hosts) == 1:
#         kvstore = 'device' if num_gpus > 0 else 'local'
#     else:
#         kvstore = 'dist_device_sync' if num_gpus > 0 else 'dist_sync'
#
#     # Get hyperparameters
#     batch_size = hyperparameters.get('batch_size', 16)
#     learning_rate = hyperparameters.get('lr', 1E-3)
#     beta1 = hyperparameters.get('beta1', 0.9)
#     beta2 = hyperparameters.get('beta2', 0.99)
#     epochs = hyperparameters.get('epochs', 100)
#     num_workers = hyperparameters.get('num_workers', 6)
#     num_classes = hyperparameters.get('num_classes', 1)
# #    class_weights = hyperparameters.get(
# #        'class_weights', [[1.35, 17.18, 8.29, 12.42]])
#     class_weights = hyperparameters.get(
#         'class_weights', [[1.35]])
#     class_weights = np.array(class_weights)
#     network = hyperparameters.get('network', 'unet')
#     assert network == 'unet' or network == 'enet', '"network" hyperparameter must be one of ["unet", "enet"]'
#
#     # Locate compressed training/validation data
#     train_dir = channel_input_dirs['train']
#     validation_dir = channel_input_dirs['test']
#     train_tars = os.listdir(train_dir)
#     validation_tars = os.listdir(validation_dir)
#     # Extract compressed image / mask pairs locally
#     for train_tar in train_tars:
#         with tarfile.open(os.path.join(train_dir, train_tar), 'r:gz') as f:
#             f.extractall(train_dir)
#     for validation_tar in validation_tars:
#         with tarfile.open(os.path.join(validation_dir, validation_tar), 'r:gz') as f:
#             f.extractall(validation_dir)
#
#     # Define custom iterators on extracted data locations.
#     train_iter = DataLoaderIter(
#         train_dir,
#         num_classes,
#         batch_size,
#         True,
#         num_workers)
#     validation_iter = DataLoaderIter(
#         validation_dir,
#         num_classes,
#         batch_size,
#         False,
#         num_workers)
#
#     # Build network symbolic graph
#     if network == 'unet':
#         sym = build_unet(num_classes, class_weights=class_weights)
#     else:
#         sym = build_enet(inp_dims=train_iter.provide_data[0][1][1:], num_classes=num_classes, class_weights=class_weights)
#     logging.info("Sym loaded")
#
#     # Load graph into Module
#     net = mx.mod.Module(sym, context=ctx, data_names=('data',), label_names=('label',))
#
#     # Initialize Custom Metric
#     dice_metric = mx.metric.CustomMetric(feval=avg_dice_coef_metric_floorplan, allow_extra_outputs=True)
#     logging.info("Starting model fit")
#
#     # Start training the model
#     net.fit(
#         train_data=train_iter,
#         eval_data=validation_iter,
#         eval_metric=dice_metric,
#         initializer=mx.initializer.Xavier(magnitude=6),
#         optimizer='adam',
#         optimizer_params={
#             'learning_rate': learning_rate,
#             'beta1': beta1,
#             'beta2': beta2},
#         num_epoch=epochs)
#
#     # Save Parameters
#     net.save_params('params')
#
#     # Build inference-only graphs, set parameters from training models
#     if network == 'unet':
#         sym = build_unet(num_classes, inference=True)
#     else:
#         sym = build_enet(
#             inp_dims=train_iter.provide_data[0][1][1:], num_classes=num_classes, inference=True)
#     net = mx.mod.Module(
#         sym, context=ctx, data_names=(
#             'data',), label_names=None)
#
#     # Re-binding model for a batch-size of one
#     net.bind(data_shapes=[('data', (1,) + train_iter.provide_data[0][1][1:])])
#     net.load_params('params')
#     return net

# %% [markdown]
# We can see that this script defines the training loop, which constitutes the life-cycle of the training job. Some points to notice:
# * **hyperparameters**: This hyperparameter mapping is something that we'll pass to the estimator as part of the training configuration.
# * **network**: This hyperparameter defines the network to train, either <tt>unet</tt> or <tt>enet</tt>.
# * **local imports**: The model, iterator, and loss/metric definitions are in local modules. We will pass this script, as well as accompanying modules, to the estimator
#
# I encourage you to look at these modules for deeper insights into training these networks.
#
# ### Local Testing using Local Mode
#
# SageMaker manages the resources and infrastructure necessary to run your training jobs, but when bringing your own script or model it is up to you to ensure that your code is bug-free.
#
# It's best practice to test your custom algorithm container locally, otherwise you'll have to wait for SageMaker to spin up your training instance(s) before receiving an error. SageMaker supports this with **Local Mode**.
#
# To run the container locally, you need to download, install, and configure docker to run locally with SageMaker. You can download the helper script below to do this:

# %%
# !wget https://raw.githubusercontent.com/awslabs/amazon-sagemaker-examples/master/sagemaker-python-sdk/mxnet_gluon_mnist/setup.sh
# !/bin/bash ./setup.sh
# Out:
# --2020-04-01 10:40:43--  https://raw.githubusercontent.com/awslabs/amazon-sagemaker-examples/master/sagemaker-python-sdk/mxnet_gluon_mnist/setup.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.184.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.184.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3003 (2.9K) [text/plain]
# Saving to: ‘setup.sh’
#
# setup.sh            100%[===================>]   2.93K  --.-KB/s    in 0s
#
# 2020-04-01 10:40:43 (69.5 MB/s) - ‘setup.sh’ saved [3003/3003]
#
# The user has root access.
# nvidia-docker2 already installed. We are good to go!
# SageMaker instance route table setup is ok. We are good to go.
# SageMaker instance routing for Docker is ok. We are good to go!

# %% [markdown]
# Next, we define the S3 input types.

# %%
sample_train_s3 = sagemaker.s3_input(s3_data=os.path.join(
    data_bucket, "sample-train"), distribution='FullyReplicated')
sample_validation_s3 = sagemaker.s3_input(s3_data=os.path.join(
    data_bucket, "sample-validation"), distribution='FullyReplicated')

# %% [markdown]
# Now we can define our estimator with training configurations, including the entry point script and directory for accompanying code. Notice we're setting <tt>train_instance_type</tt> to <tt>local</tt>.

# %%
local_unet_job = 'cubicasa5k-local-unet-job-' + \
    time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())

local_estimator = MXNet(entry_point='floorplan_segmentation.py',
                        base_job_name=local_unet_job,
                        source_dir='source_dir',
                        role=role,
                        py_version='py3',
                        train_instance_count=1,
                        train_instance_type='local',
                        hyperparameters={
                            'learning_rate': 1E-3 * 16,
                            'class_weights': [[1.35, 17.18]],
                            'network': 'unet',
                            'batch_size': 8,
                            'num_classes': 2,
                            'epochs': 1
                        })
# Out:
# No framework_version specified, defaulting to version 1.2. This is not the latest supported version. If you would like to use version 1.6.0, please add framework_version=1.6.0 to your constructor.

# %% [markdown]
# Now we call <tt>fit</tt> on the S3 inputs, mapping <tt>train</tt> and <tt>test</tt> labels to each. Since we're in local mode, the container will be downloaded and ran locally.

# %%
#!cat /tmp/tmp2keu1y9u/docker-compose.yaml
local_estimator.fit({'train': sample_train_s3, 'test': sample_validation_s3})
# Out:
# Creating tmp9o951ogb_algo-1-3qxuf_1 ...
# Attaching to tmp9o951ogb_algo-1-3qxuf_12mdone
# algo-1-3qxuf_1  | 2020-04-01 10:40:51,740 INFO - root - running container entrypoint
# algo-1-3qxuf_1  | 2020-04-01 10:40:51,740 INFO - root - starting train task
# algo-1-3qxuf_1  | 2020-04-01 10:40:51,744 INFO - container_support.training - Training starting
# algo-1-3qxuf_1  | 2020-04-01 10:40:52,929 WARNING - mxnet_container.train - This required structure for training scripts will be deprecated with the next major release of MXNet images. The train() function will no longer be required; instead the training script must be able to be run as a standalone script. For more information, see https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/mxnet#updating-your-mxnet-training-script.
# algo-1-3qxuf_1  | 2020-04-01 10:40:52,941 INFO - mxnet_container.train - MXNetTrainingEnvironment: {'input_dir': '/opt/ml/input', 'channel_dirs': {'train': '/opt/ml/input/data/train', 'test': '/opt/ml/input/data/test'}, 'available_gpus': 0, 'hosts': ['algo-1-3qxuf'], '_scheduler_ip': '172.18.0.3', 'channels': {'train': {'TrainingInputMode': 'File'}, 'test': {'TrainingInputMode': 'File'}}, 'user_script_archive': 's3://sagemaker-us-east-2-308537982265/cubicasa5k-local-unet-job-2020-04-01-10-2020-04-01-10-40-48-448/source/sourcedir.tar.gz', 'code_dir': '/opt/ml/code', 'base_dir': '/opt/ml', 'user_requirements_file': None, 'model_dir': '/opt/ml/model', 'input_config_dir': '/opt/ml/input/config', 'container_log_level': 20, 'user_script_name': 'floorplan_segmentation.py', 'available_cpus': 8, 'sagemaker_region': 'us-east-2', 'hyperparameters': {'num_classes': 2, 'learning_rate': 0.016, 'batch_size': 8, 'sagemaker_job_name': 'cubicasa5k-local-unet-job-2020-04-01-10-2020-04-01-10-40-48-448', 'sagemaker_region': 'us-east-2', 'class_weights': [[1.35, 17.18]], 'sagemaker_submit_directory': 's3://sagemaker-us-east-2-308537982265/cubicasa5k-local-unet-job-2020-04-01-10-2020-04-01-10-40-48-448/source/sourcedir.tar.gz', 'sagemaker_program': 'floorplan_segmentation.py', 'network': 'unet', 'sagemaker_container_log_level': 20, 'epochs': 1, 'sagemaker_enable_cloudwatch_metrics': False}, '_ps_port': 8000, 'current_host': 'algo-1-3qxuf', 'enable_cloudwatch_metrics': False, '_scheduler_host': 'algo-1-3qxuf', 'resource_config': {'current_host': 'algo-1-3qxuf', 'hosts': ['algo-1-3qxuf']}, 'job_name': 'cubicasa5k-local-unet-job-2020-04-01-10-2020-04-01-10-40-48-448', 'output_data_dir': '/opt/ml/output/data/', 'output_dir': '/opt/ml/output', '_ps_verbose': 0}
# algo-1-3qxuf_1  | Downloading s3://sagemaker-us-east-2-308537982265/cubicasa5k-local-unet-job-2020-04-01-10-2020-04-01-10-40-48-448/source/sourcedir.tar.gz to /tmp/script.tar.gz
# algo-1-3qxuf_1  | 2020-04-01 10:40:53,156 INFO - mxnet_container.train - Starting distributed training task
# algo-1-3qxuf_1  | /usr/local/lib/python3.5/dist-packages/mxnet_container/train.py:190: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
# algo-1-3qxuf_1  |   train_args = inspect.getargspec(user_module.train)
# algo-1-3qxuf_1  | 2020-04-01 10:40:53,175 INFO - root - 1.2.1
# algo-1-3qxuf_1  | 2020-04-01 10:40:53,199 INFO - root - Sym loaded
# algo-1-3qxuf_1  | 2020-04-01 10:40:53,200 INFO - root - Starting model fit
# algo-1-3qxuf_1  | 2020-04-01 10:40:54,538 INFO - root - Epoch[0] Train-avg_dice_coef_metric_floorplan=0.522461
# algo-1-3qxuf_1  | 2020-04-01 10:40:54,539 INFO - root - Epoch[0] Time cost=1.159
# algo-1-3qxuf_1  | 2020-04-01 10:40:57,781 INFO - root - Epoch[0] Validation-avg_dice_coef_metric_floorplan=0.535513
# tmp9o951ogb_algo-1-3qxuf_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# Next, we can test the serving image locally as well by calling <tt>deploy</tt>.

# %%
#check if there are any processes already running locally on 8080 from previous serving runs and kill them
# !ps aux | grep 8080
# !ps aux | grep moby
# !sudo kill -9 14257
# Out:
# root     26193  0.0  0.0 126052  1020 ?        Sl   Mar30   0:00 /usr/bin/docker-proxy -proto tcp -host-ip 0.0.0.0 -host-port 8080 -container-ip 172.18.0.2 -container-port 8080
# ec2-user 27073  1.0  0.0 113156  2724 pts/3    Ss+  10:41   0:00 /bin/sh -c ps aux | grep 8080
# ec2-user 27075  0.0  0.0 110532  2048 pts/3    S+   10:41   0:00 grep 8080
# root     26200  0.0  0.0 109032   848 ?        Sl   Mar30   0:05 containerd-shim -namespace moby -workdir /var/lib/docker/containerd/daemon/io.containerd.runtime.v1.linux/moby/d83c04e607f1943c50bf42900da526d3adfe7f005fa89c572431f81bf65b32c0 -address /var/run/docker/containerd/containerd.sock -containerd-binary /usr/bin/containerd -runtime-root /var/run/docker/runtime-runc
# ec2-user 27076  1.0  0.0 113156  2684 pts/3    Ss+  10:41   0:00 /bin/sh -c ps aux | grep moby
# ec2-user 27078  0.0  0.0 110532  2136 pts/3    S+   10:41   0:00 grep moby
# kill: sending signal to 14257 failed: No such process

# %%
local_unet_endpoint = 'cubicasa5k-local-unet-endpoint-' + \
    time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())

local_predictor = local_estimator.deploy(initial_instance_count=1, instance_type='local-gpu',
                                         endpoint_name=local_unet_endpoint)
# Out:
# !

# %% [markdown]
# The <tt>deploy</tt> method returns a <tt>predictor</tt>, which we can use to submit requests to the endpoint. An endpoint is a containerized application serving inference using your model artifact, which we'll test locally.
#
# Let's load a test image into memory to submit for inference:

# %%
from PIL import Image
test_brain = np.array(Image.open(os.path.join(
    validation_dir, '147.png')))[np.newaxis, np.newaxis, :]
test_mask = np.array(Image.open(os.path.join(
    validation_dir, '147_mask.png')))[np.newaxis, np.newaxis, :]

response = local_predictor.predict(test_brain.tolist())
output = np.argmax(np.array(response), axis=(1))[0].astype(np.uint8)
plt.figure(figsize=(14, 14))
plt.subplot(131)
plt.title('Input')
plt.imshow(test_brain[0][0], cmap=plt.cm.gray)
plt.subplot(132)
plt.title('Ground Truth')
plt.imshow(test_mask[0][0], cmap=plt.cm.gray)
plt.subplot(133)
plt.title('Prediction')
plt.imshow(output, cmap=plt.cm.gray)
# Out:
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/sagemaker/local/image.py", line 614, in run
#     _stream_output(self.process)
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/sagemaker/local/image.py", line 673, in _stream_output
#     raise RuntimeError("Process exited with code: %s" % exit_code)
# RuntimeError: Process exited with code: 1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/sagemaker/local/image.py", line 619, in run
#     raise RuntimeError(msg)
# RuntimeError: Failed to run: ['docker-compose', '-f', '/tmp/tmp48ajc5fl/docker-compose.yaml', 'up', '--build', '--abort-on-container-exit'], Process exited with code: 1

# %% [markdown]
# The result is predictably terrible, given the small sample set and one epoch of training.
#
# Now that we've tested our images, we can launch training jobs and endpoints.
#
# ### UNet
#
# We'll first train U-Net as a baseline for comparison with the faster, lightweight ENet.

# %%
unet_single_machine_job = 'cubicasa-unet-single-machine-job-' + \
    time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())

unet_single_machine_estimator = MXNet(entry_point='floorplan_segmentation.py',
                                      base_job_name=unet_single_machine_job,
                                      source_dir='source_dir',
                                      role=role,
                                      py_version='py3',
                                      train_instance_count=1,
                                      train_instance_type='ml.p3.2xlarge',
                                      hyperparameters={
                                          'learning_rate': 1E-3,
                                          'num_classes':2,
                                          'class_weights': [[1.35, 17.18]],
                                          'network': 'unet',
                                          'batch_size': 32,
                                      })
# Out:
# No framework_version specified, defaulting to version 1.2. This is not the latest supported version. If you would like to use version 1.6.0, please add framework_version=1.6.0 to your constructor.

# %% [markdown]
# This time, we'll train on the entire training set, and validate on the entire validation set.

# %%
train_s3 = sagemaker.s3_input(s3_data=os.path.join(data_bucket, "train"), distribution='FullyReplicated')
validation_s3 = sagemaker.s3_input(s3_data=os.path.join(data_bucket, "validation"), distribution='FullyReplicated')

unet_single_machine_estimator.fit({'train': train_s3, 'test': validation_s3})
# Out:
# 2020-03-30 06:02:45 Starting - Starting the training job...
# 2020-03-30 06:02:47 Starting - Launching requested ML instances...
# 2020-03-30 06:03:44 Starting - Preparing the instances for training......
# 2020-03-30 06:04:33 Downloading - Downloading input data...
# 2020-03-30 06:04:47 Training - Downloading the training image..2020-03-30 06:05:25,451 INFO - root - running container entrypoint
# 2020-03-30 06:05:25,452 INFO - root - starting train task
# 2020-03-30 06:05:25,471 INFO - container_support.training - Training starting
# 2020-03-30 06:05:26,461 WARNING - mxnet_container.train - #033This required structure for training scripts will be deprecated with the next major release of MXNet images. The train() function will no longer be required; instead the training script must be able to be run as a standalone script. For more information, see https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/mxnet#updating-your-mxnet-training-script.#033
# 2020-03-30 06:05:26,901 INFO - mxnet_container.train - MXNetTrainingEnvironment: {'_scheduler_ip': '10.0.140.216', 'output_dir': '/opt/ml/output', 'input_dir': '/opt/ml/input', 'user_script_name': 'floorplan_segmentation.py', '_scheduler_host': 'algo-1', 'channel_dirs': {'train': '/opt/ml/input/data/train', 'test': '/opt/ml/input/data/test'}, 'hosts': ['algo-1'], 'base_dir': '/opt/ml', 'output_data_dir': '/opt/ml/output/data/', 'input_config_dir': '/opt/ml/input/config', 'model_dir': '/opt/ml/model', 'resource_config': {'hosts': ['algo-1'], 'network_interface_name': 'eth0', 'current_host': 'algo-1'}, '_ps_port': 8000, 'current_host': 'algo-1', 'channels': {'train': {'S3DistributionType': 'FullyReplicated', 'RecordWrapperType': 'None', 'TrainingInputMode': 'File'}, 'test': {'S3DistributionType': 'FullyReplicated', 'RecordWrapperType': 'None', 'TrainingInputMode': 'File'}}, 'container_log_level': 20, 'available_gpus': 1, '_ps_verbose': 0, 'hyperparameters': {'network': 'unet', 'batch_size': 32, 'sagemaker_enable_cloudwatch_metrics': False, 'sagemaker_submit_directory': 's3://sagemaker-us-east-2-308537982265/cubicasa-unet-single-machine-job-2020-0-2020-03-30-06-02-45-296/source/sourcedir.tar.gz', 'learning_rate': 0.001, 'num_classes': 2, 'sagemaker_container_log_level': 20, 'sagemaker_program': 'floorplan_segmentation.py', 'sagemaker_job_name': 'cubicasa-unet-single-machine-job-2020-0-2020-03-30-06-02-45-296', 'sagemaker_region': 'us-east-2', 'class_weights': [[1.35, 17.18]]}, 'code_dir': '/opt/ml/code', 'user_requirements_file': None, 'job_name': 'cubicasa-unet-single-machine-job-2020-0-2020-03-30-06-02-45-296', 'available_cpus': 8, 'enable_cloudwatch_metrics': False, 'sagemaker_region': 'us-east-2', 'user_script_archive': 's3://sagemaker-us-east-2-308537982265/cubicasa-unet-single-machine-job-2020-0-2020-03-30-06-02-45-296/source/sourcedir.tar.gz'}
# Downloading s3://sagemaker-us-east-2-308537982265/cubicasa-unet-single-machine-job-2020-0-2020-03-30-06-02-45-296/source/sourcedir.tar.gz to /tmp/script.tar.gz
# 2020-03-30 06:05:27,149 INFO - mxnet_container.train - Starting distributed training task
# /usr/local/lib/python3.5/dist-packages/mxnet_container/train.py:190: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   train_args = inspect.getargspec(user_module.train)
# 2020-03-30 06:05:27,168 INFO - root - 1.2.1
# 2020-03-30 06:05:27,472 INFO - root - Sym loaded
# 2020-03-30 06:05:27,474 INFO - root - Starting model fit
#
# 2020-03-30 06:05:25 Training - Training image download completed. Training in progress.[06:05:36] src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:107: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [06:05:37] src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:107: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# 2020-03-30 06:05:39,485 INFO - root - Epoch[0] Train-avg_dice_coef_metric_floorplan=0.318984
# 2020-03-30 06:05:39,485 INFO - root - Epoch[0] Time cost=3.359
# 2020-03-30 06:05:39,937 INFO - root - Epoch[0] Validation-avg_dice_coef_metric_floorplan=0.266756
# 2020-03-30 06:05:41,616 INFO - root - Epoch[1] Train-avg_dice_coef_metric_floorplan=0.136884
# 2020-03-30 06:05:41,616 INFO - root - Epoch[1] Time cost=1.679
# 2020-03-30 06:05:42,147 INFO - root - Epoch[1] Validation-avg_dice_coef_metric_floorplan=0.177354
# 2020-03-30 06:05:43,769 INFO - root - Epoch[2] Train-avg_dice_coef_metric_floorplan=0.106250
# 2020-03-30 06:05:43,769 INFO - root - Epoch[2] Time cost=1.621
# 2020-03-30 06:05:44,218 INFO - root - Epoch[2] Validation-avg_dice_coef_metric_floorplan=0.123116
# 2020-03-30 06:05:45,905 INFO - root - Epoch[3] Train-avg_dice_coef_metric_floorplan=0.105698
# 2020-03-30 06:05:45,906 INFO - root - Epoch[3] Time cost=1.688
# 2020-03-30 06:05:46,449 INFO - root - Epoch[3] Validation-avg_dice_coef_metric_floorplan=0.121315
# 2020-03-30 06:05:48,077 INFO - root - Epoch[4] Train-avg_dice_coef_metric_floorplan=0.095294
# 2020-03-30 06:05:48,078 INFO - root - Epoch[4] Time cost=1.628
# 2020-03-30 06:05:48,557 INFO - root - Epoch[4] Validation-avg_dice_coef_metric_floorplan=0.107504
# 2020-03-30 06:05:50,285 INFO - root - Epoch[5] Train-avg_dice_coef_metric_floorplan=0.088772
# 2020-03-30 06:05:50,286 INFO - root - Epoch[5] Time cost=1.728
# 2020-03-30 06:05:50,802 INFO - root - Epoch[5] Validation-avg_dice_coef_metric_floorplan=0.097209
# 2020-03-30 06:05:52,468 INFO - root - Epoch[6] Train-avg_dice_coef_metric_floorplan=0.087779
# 2020-03-30 06:05:52,468 INFO - root - Epoch[6] Time cost=1.665
# 2020-03-30 06:05:52,930 INFO - root - Epoch[6] Validation-avg_dice_coef_metric_floorplan=0.099407
# 2020-03-30 06:05:54,636 INFO - root - Epoch[7] Train-avg_dice_coef_metric_floorplan=0.077361
# 2020-03-30 06:05:54,636 INFO - root - Epoch[7] Time cost=1.706
# 2020-03-30 06:05:55,162 INFO - root - Epoch[7] Validation-avg_dice_coef_metric_floorplan=0.115306
# 2020-03-30 06:05:56,868 INFO - root - Epoch[8] Train-avg_dice_coef_metric_floorplan=0.072335
# 2020-03-30 06:05:56,868 INFO - root - Epoch[8] Time cost=1.705
# 2020-03-30 06:05:57,326 INFO - root - Epoch[8] Validation-avg_dice_coef_metric_floorplan=0.099734
# 2020-03-30 06:05:58,972 INFO - root - Epoch[9] Train-avg_dice_coef_metric_floorplan=0.070207
# 2020-03-30 06:05:58,973 INFO - root - Epoch[9] Time cost=1.647
# 2020-03-30 06:05:59,492 INFO - root - Epoch[9] Validation-avg_dice_coef_metric_floorplan=0.102446
# 2020-03-30 06:06:01,210 INFO - root - Epoch[10] Train-avg_dice_coef_metric_floorplan=0.069138
# 2020-03-30 06:06:01,210 INFO - root - Epoch[10] Time cost=1.718
# 2020-03-30 06:06:01,693 INFO - root - Epoch[10] Validation-avg_dice_coef_metric_floorplan=0.093366
# 2020-03-30 06:06:03,407 INFO - root - Epoch[11] Train-avg_dice_coef_metric_floorplan=0.066598
# 2020-03-30 06:06:03,407 INFO - root - Epoch[11] Time cost=1.714
# 2020-03-30 06:06:03,934 INFO - root - Epoch[11] Validation-avg_dice_coef_metric_floorplan=0.098457
# 2020-03-30 06:06:05,561 INFO - root - Epoch[12] Train-avg_dice_coef_metric_floorplan=0.063892
# 2020-03-30 06:06:05,561 INFO - root - Epoch[12] Time cost=1.626
# 2020-03-30 06:06:06,035 INFO - root - Epoch[12] Validation-avg_dice_coef_metric_floorplan=0.091219
# 2020-03-30 06:06:07,753 INFO - root - Epoch[13] Train-avg_dice_coef_metric_floorplan=0.056846
# 2020-03-30 06:06:07,753 INFO - root - Epoch[13] Time cost=1.718
# 2020-03-30 06:06:08,284 INFO - root - Epoch[13] Validation-avg_dice_coef_metric_floorplan=0.089893
# 2020-03-30 06:06:10,002 INFO - root - Epoch[14] Train-avg_dice_coef_metric_floorplan=0.055882
# 2020-03-30 06:06:10,002 INFO - root - Epoch[14] Time cost=1.718
# 2020-03-30 06:06:10,467 INFO - root - Epoch[14] Validation-avg_dice_coef_metric_floorplan=0.102883
# 2020-03-30 06:06:12,169 INFO - root - Epoch[15] Train-avg_dice_coef_metric_floorplan=0.051618
# 2020-03-30 06:06:12,169 INFO - root - Epoch[15] Time cost=1.702
# 2020-03-30 06:06:12,696 INFO - root - Epoch[15] Validation-avg_dice_coef_metric_floorplan=0.095740
# 2020-03-30 06:06:14,411 INFO - root - Epoch[16] Train-avg_dice_coef_metric_floorplan=0.054196
# 2020-03-30 06:06:14,411 INFO - root - Epoch[16] Time cost=1.714
# 2020-03-30 06:06:14,878 INFO - root - Epoch[16] Validation-avg_dice_coef_metric_floorplan=0.094979
# 2020-03-30 06:06:16,578 INFO - root - Epoch[17] Train-avg_dice_coef_metric_floorplan=0.051771
# 2020-03-30 06:06:16,579 INFO - root - Epoch[17] Time cost=1.701
# 2020-03-30 06:06:17,096 INFO - root - Epoch[17] Validation-avg_dice_coef_metric_floorplan=0.082331
# 2020-03-30 06:06:18,836 INFO - root - Epoch[18] Train-avg_dice_coef_metric_floorplan=0.046971
# 2020-03-30 06:06:18,837 INFO - root - Epoch[18] Time cost=1.740
# 2020-03-30 06:06:19,298 INFO - root - Epoch[18] Validation-avg_dice_coef_metric_floorplan=0.083167
# 2020-03-30 06:06:20,934 INFO - root - Epoch[19] Train-avg_dice_coef_metric_floorplan=0.044906
# 2020-03-30 06:06:20,934 INFO - root - Epoch[19] Time cost=1.635
# 2020-03-30 06:06:21,483 INFO - root - Epoch[19] Validation-avg_dice_coef_metric_floorplan=0.082013
# 2020-03-30 06:06:23,194 INFO - root - Epoch[20] Train-avg_dice_coef_metric_floorplan=0.044920
# 2020-03-30 06:06:23,194 INFO - root - Epoch[20] Time cost=1.711
# 2020-03-30 06:06:23,672 INFO - root - Epoch[20] Validation-avg_dice_coef_metric_floorplan=0.095180
# 2020-03-30 06:06:25,300 INFO - root - Epoch[21] Train-avg_dice_coef_metric_floorplan=0.046874
# 2020-03-30 06:06:25,301 INFO - root - Epoch[21] Time cost=1.626
# 2020-03-30 06:06:25,811 INFO - root - Epoch[21] Validation-avg_dice_coef_metric_floorplan=0.092993
# 2020-03-30 06:06:27,523 INFO - root - Epoch[22] Train-avg_dice_coef_metric_floorplan=0.045861
# 2020-03-30 06:06:27,523 INFO - root - Epoch[22] Time cost=1.712
# 2020-03-30 06:06:27,985 INFO - root - Epoch[22] Validation-avg_dice_coef_metric_floorplan=0.099939
# 2020-03-30 06:06:29,628 INFO - root - Epoch[23] Train-avg_dice_coef_metric_floorplan=0.045255
# 2020-03-30 06:06:29,628 INFO - root - Epoch[23] Time cost=1.642
# 2020-03-30 06:06:30,168 INFO - root - Epoch[23] Validation-avg_dice_coef_metric_floorplan=0.109330
# 2020-03-30 06:06:31,810 INFO - root - Epoch[24] Train-avg_dice_coef_metric_floorplan=0.047443
# 2020-03-30 06:06:31,810 INFO - root - Epoch[24] Time cost=1.642
# 2020-03-30 06:06:32,289 INFO - root - Epoch[24] Validation-avg_dice_coef_metric_floorplan=0.096956
# 2020-03-30 06:06:34,010 INFO - root - Epoch[25] Train-avg_dice_coef_metric_floorplan=0.043528
# 2020-03-30 06:06:34,010 INFO - root - Epoch[25] Time cost=1.720
# 2020-03-30 06:06:34,530 INFO - root - Epoch[25] Validation-avg_dice_coef_metric_floorplan=0.088854
# 2020-03-30 06:06:36,245 INFO - root - Epoch[26] Train-avg_dice_coef_metric_floorplan=0.039663
# 2020-03-30 06:06:36,246 INFO - root - Epoch[26] Time cost=1.715
# 2020-03-30 06:06:36,722 INFO - root - Epoch[26] Validation-avg_dice_coef_metric_floorplan=0.087464
# 2020-03-30 06:06:38,365 INFO - root - Epoch[27] Train-avg_dice_coef_metric_floorplan=0.041044
# 2020-03-30 06:06:38,366 INFO - root - Epoch[27] Time cost=1.643
# 2020-03-30 06:06:38,906 INFO - root - Epoch[27] Validation-avg_dice_coef_metric_floorplan=0.088450
# 2020-03-30 06:06:40,631 INFO - root - Epoch[28] Train-avg_dice_coef_metric_floorplan=0.037848
# 2020-03-30 06:06:40,631 INFO - root - Epoch[28] Time cost=1.725
# 2020-03-30 06:06:41,108 INFO - root - Epoch[28] Validation-avg_dice_coef_metric_floorplan=0.081231
# 2020-03-30 06:06:42,825 INFO - root - Epoch[29] Train-avg_dice_coef_metric_floorplan=0.037019
# 2020-03-30 06:06:42,825 INFO - root - Epoch[29] Time cost=1.717
# 2020-03-30 06:06:43,373 INFO - root - Epoch[29] Validation-avg_dice_coef_metric_floorplan=0.081031
# 2020-03-30 06:06:45,006 INFO - root - Epoch[30] Train-avg_dice_coef_metric_floorplan=0.037437
# 2020-03-30 06:06:45,006 INFO - root - Epoch[30] Time cost=1.632
# 2020-03-30 06:06:45,484 INFO - root - Epoch[30] Validation-avg_dice_coef_metric_floorplan=0.090140
# 2020-03-30 06:06:47,117 INFO - root - Epoch[31] Train-avg_dice_coef_metric_floorplan=0.035623
# 2020-03-30 06:06:47,117 INFO - root - Epoch[31] Time cost=1.632
# 2020-03-30 06:06:47,656 INFO - root - Epoch[31] Validation-avg_dice_coef_metric_floorplan=0.083496
# 2020-03-30 06:06:49,284 INFO - root - Epoch[32] Train-avg_dice_coef_metric_floorplan=0.032854
# 2020-03-30 06:06:49,284 INFO - root - Epoch[32] Time cost=1.628
# 2020-03-30 06:06:49,769 INFO - root - Epoch[32] Validation-avg_dice_coef_metric_floorplan=0.079248
# 2020-03-30 06:06:51,432 INFO - root - Epoch[33] Train-avg_dice_coef_metric_floorplan=0.035116
# 2020-03-30 06:06:51,432 INFO - root - Epoch[33] Time cost=1.663
# 2020-03-30 06:06:51,952 INFO - root - Epoch[33] Validation-avg_dice_coef_metric_floorplan=0.085323
# 2020-03-30 06:06:53,605 INFO - root - Epoch[34] Train-avg_dice_coef_metric_floorplan=0.031392
# 2020-03-30 06:06:53,605 INFO - root - Epoch[34] Time cost=1.648
# 2020-03-30 06:06:54,058 INFO - root - Epoch[34] Validation-avg_dice_coef_metric_floorplan=0.083439
# 2020-03-30 06:06:55,751 INFO - root - Epoch[35] Train-avg_dice_coef_metric_floorplan=0.031314
# 2020-03-30 06:06:55,751 INFO - root - Epoch[35] Time cost=1.692
# 2020-03-30 06:06:56,281 INFO - root - Epoch[35] Validation-avg_dice_coef_metric_floorplan=0.083566
# 2020-03-30 06:06:58,019 INFO - root - Epoch[36] Train-avg_dice_coef_metric_floorplan=0.033650
# 2020-03-30 06:06:58,019 INFO - root - Epoch[36] Time cost=1.737
# 2020-03-30 06:06:58,496 INFO - root - Epoch[36] Validation-avg_dice_coef_metric_floorplan=0.080478
# 2020-03-30 06:07:00,219 INFO - root - Epoch[37] Train-avg_dice_coef_metric_floorplan=0.031023
# 2020-03-30 06:07:00,219 INFO - root - Epoch[37] Time cost=1.722
# 2020-03-30 06:07:00,757 INFO - root - Epoch[37] Validation-avg_dice_coef_metric_floorplan=0.082824
# 2020-03-30 06:07:02,390 INFO - root - Epoch[38] Train-avg_dice_coef_metric_floorplan=0.030618
# 2020-03-30 06:07:02,390 INFO - root - Epoch[38] Time cost=1.633
# 2020-03-30 06:07:02,875 INFO - root - Epoch[38] Validation-avg_dice_coef_metric_floorplan=0.080690
# 2020-03-30 06:07:04,579 INFO - root - Epoch[39] Train-avg_dice_coef_metric_floorplan=0.029555
# 2020-03-30 06:07:04,579 INFO - root - Epoch[39] Time cost=1.703
# 2020-03-30 06:07:05,125 INFO - root - Epoch[39] Validation-avg_dice_coef_metric_floorplan=0.083266
# 2020-03-30 06:07:06,766 INFO - root - Epoch[40] Train-avg_dice_coef_metric_floorplan=0.030676
# 2020-03-30 06:07:06,766 INFO - root - Epoch[40] Time cost=1.641
# 2020-03-30 06:07:07,237 INFO - root - Epoch[40] Validation-avg_dice_coef_metric_floorplan=0.084664
# 2020-03-30 06:07:08,960 INFO - root - Epoch[41] Train-avg_dice_coef_metric_floorplan=0.027331
# 2020-03-30 06:07:08,961 INFO - root - Epoch[41] Time cost=1.723
# 2020-03-30 06:07:09,495 INFO - root - Epoch[41] Validation-avg_dice_coef_metric_floorplan=0.091103
# 2020-03-30 06:07:11,220 INFO - root - Epoch[42] Train-avg_dice_coef_metric_floorplan=0.027259
# 2020-03-30 06:07:11,220 INFO - root - Epoch[42] Time cost=1.725
# 2020-03-30 06:07:11,679 INFO - root - Epoch[42] Validation-avg_dice_coef_metric_floorplan=0.076965
# 2020-03-30 06:07:13,392 INFO - root - Epoch[43] Train-avg_dice_coef_metric_floorplan=0.026103
# 2020-03-30 06:07:13,392 INFO - root - Epoch[43] Time cost=1.712
# 2020-03-30 06:07:13,920 INFO - root - Epoch[43] Validation-avg_dice_coef_metric_floorplan=0.083000
# 2020-03-30 06:07:15,640 INFO - root - Epoch[44] Train-avg_dice_coef_metric_floorplan=0.026483
# 2020-03-30 06:07:15,640 INFO - root - Epoch[44] Time cost=1.720
# 2020-03-30 06:07:16,131 INFO - root - Epoch[44] Validation-avg_dice_coef_metric_floorplan=0.076532
# 2020-03-30 06:07:17,770 INFO - root - Epoch[45] Train-avg_dice_coef_metric_floorplan=0.028281
# 2020-03-30 06:07:17,770 INFO - root - Epoch[45] Time cost=1.638
# 2020-03-30 06:07:18,306 INFO - root - Epoch[45] Validation-avg_dice_coef_metric_floorplan=0.086591
# 2020-03-30 06:07:20,025 INFO - root - Epoch[46] Train-avg_dice_coef_metric_floorplan=0.028641
# 2020-03-30 06:07:20,025 INFO - root - Epoch[46] Time cost=1.719
# 2020-03-30 06:07:20,501 INFO - root - Epoch[46] Validation-avg_dice_coef_metric_floorplan=0.086678
# 2020-03-30 06:07:22,141 INFO - root - Epoch[47] Train-avg_dice_coef_metric_floorplan=0.028836
# 2020-03-30 06:07:22,142 INFO - root - Epoch[47] Time cost=1.640
# 2020-03-30 06:07:22,697 INFO - root - Epoch[47] Validation-avg_dice_coef_metric_floorplan=0.092156
# 2020-03-30 06:07:24,377 INFO - root - Epoch[48] Train-avg_dice_coef_metric_floorplan=0.027084
# 2020-03-30 06:07:24,377 INFO - root - Epoch[48] Time cost=1.680
# 2020-03-30 06:07:24,848 INFO - root - Epoch[48] Validation-avg_dice_coef_metric_floorplan=0.112217
# 2020-03-30 06:07:26,572 INFO - root - Epoch[49] Train-avg_dice_coef_metric_floorplan=0.027595
# 2020-03-30 06:07:26,572 INFO - root - Epoch[49] Time cost=1.723
# 2020-03-30 06:07:27,118 INFO - root - Epoch[49] Validation-avg_dice_coef_metric_floorplan=0.077521
# 2020-03-30 06:07:28,832 INFO - root - Epoch[50] Train-avg_dice_coef_metric_floorplan=0.025377
# 2020-03-30 06:07:28,832 INFO - root - Epoch[50] Time cost=1.713
# 2020-03-30 06:07:29,321 INFO - root - Epoch[50] Validation-avg_dice_coef_metric_floorplan=0.079131
# 2020-03-30 06:07:31,070 INFO - root - Epoch[51] Train-avg_dice_coef_metric_floorplan=0.023366
# 2020-03-30 06:07:31,071 INFO - root - Epoch[51] Time cost=1.749
# 2020-03-30 06:07:31,610 INFO - root - Epoch[51] Validation-avg_dice_coef_metric_floorplan=0.074654
# 2020-03-30 06:07:33,333 INFO - root - Epoch[52] Train-avg_dice_coef_metric_floorplan=0.022247
# 2020-03-30 06:07:33,333 INFO - root - Epoch[52] Time cost=1.723
# 2020-03-30 06:07:33,827 INFO - root - Epoch[52] Validation-avg_dice_coef_metric_floorplan=0.074212
# 2020-03-30 06:07:35,564 INFO - root - Epoch[53] Train-avg_dice_coef_metric_floorplan=0.022925
# 2020-03-30 06:07:35,564 INFO - root - Epoch[53] Time cost=1.737
# 2020-03-30 06:07:36,106 INFO - root - Epoch[53] Validation-avg_dice_coef_metric_floorplan=0.076425
# 2020-03-30 06:07:37,826 INFO - root - Epoch[54] Train-avg_dice_coef_metric_floorplan=0.023484
# 2020-03-30 06:07:37,826 INFO - root - Epoch[54] Time cost=1.720
# 2020-03-30 06:07:38,298 INFO - root - Epoch[54] Validation-avg_dice_coef_metric_floorplan=0.077697
# 2020-03-30 06:07:40,025 INFO - root - Epoch[55] Train-avg_dice_coef_metric_floorplan=0.022059
# 2020-03-30 06:07:40,025 INFO - root - Epoch[55] Time cost=1.726
# 2020-03-30 06:07:40,576 INFO - root - Epoch[55] Validation-avg_dice_coef_metric_floorplan=0.072482
# 2020-03-30 06:07:42,224 INFO - root - Epoch[56] Train-avg_dice_coef_metric_floorplan=0.020729
# 2020-03-30 06:07:42,224 INFO - root - Epoch[56] Time cost=1.648
# 2020-03-30 06:07:42,692 INFO - root - Epoch[56] Validation-avg_dice_coef_metric_floorplan=0.072904
# 2020-03-30 06:07:44,350 INFO - root - Epoch[57] Train-avg_dice_coef_metric_floorplan=0.019651
# 2020-03-30 06:07:44,351 INFO - root - Epoch[57] Time cost=1.659
# 2020-03-30 06:07:44,867 INFO - root - Epoch[57] Validation-avg_dice_coef_metric_floorplan=0.073307
# 2020-03-30 06:07:46,506 INFO - root - Epoch[58] Train-avg_dice_coef_metric_floorplan=0.018489
# 2020-03-30 06:07:46,506 INFO - root - Epoch[58] Time cost=1.638
# 2020-03-30 06:07:46,982 INFO - root - Epoch[58] Validation-avg_dice_coef_metric_floorplan=0.073202
# 2020-03-30 06:07:48,697 INFO - root - Epoch[59] Train-avg_dice_coef_metric_floorplan=0.017634
# 2020-03-30 06:07:48,698 INFO - root - Epoch[59] Time cost=1.715
# 2020-03-30 06:07:49,238 INFO - root - Epoch[59] Validation-avg_dice_coef_metric_floorplan=0.070159
# 2020-03-30 06:07:50,897 INFO - root - Epoch[60] Train-avg_dice_coef_metric_floorplan=0.017860
# 2020-03-30 06:07:50,897 INFO - root - Epoch[60] Time cost=1.658
# 2020-03-30 06:07:51,387 INFO - root - Epoch[60] Validation-avg_dice_coef_metric_floorplan=0.073527
# 2020-03-30 06:07:53,118 INFO - root - Epoch[61] Train-avg_dice_coef_metric_floorplan=0.017117
# 2020-03-30 06:07:53,118 INFO - root - Epoch[61] Time cost=1.731
# 2020-03-30 06:07:53,661 INFO - root - Epoch[61] Validation-avg_dice_coef_metric_floorplan=0.067795
# 2020-03-30 06:07:55,393 INFO - root - Epoch[62] Train-avg_dice_coef_metric_floorplan=0.017429
# 2020-03-30 06:07:55,393 INFO - root - Epoch[62] Time cost=1.731
# 2020-03-30 06:07:55,888 INFO - root - Epoch[62] Validation-avg_dice_coef_metric_floorplan=0.072097
# 2020-03-30 06:07:57,626 INFO - root - Epoch[63] Train-avg_dice_coef_metric_floorplan=0.018008
# 2020-03-30 06:07:57,627 INFO - root - Epoch[63] Time cost=1.736
# 2020-03-30 06:07:58,156 INFO - root - Epoch[63] Validation-avg_dice_coef_metric_floorplan=0.073644
# 2020-03-30 06:07:59,898 INFO - root - Epoch[64] Train-avg_dice_coef_metric_floorplan=0.018119
# 2020-03-30 06:07:59,898 INFO - root - Epoch[64] Time cost=1.742
# 2020-03-30 06:08:00,391 INFO - root - Epoch[64] Validation-avg_dice_coef_metric_floorplan=0.075272
# 2020-03-30 06:08:02,131 INFO - root - Epoch[65] Train-avg_dice_coef_metric_floorplan=0.017779
# 2020-03-30 06:08:02,131 INFO - root - Epoch[65] Time cost=1.740
# 2020-03-30 06:08:02,677 INFO - root - Epoch[65] Validation-avg_dice_coef_metric_floorplan=0.070026
# 2020-03-30 06:08:04,406 INFO - root - Epoch[66] Train-avg_dice_coef_metric_floorplan=0.016744
# 2020-03-30 06:08:04,406 INFO - root - Epoch[66] Time cost=1.729
# 2020-03-30 06:08:04,880 INFO - root - Epoch[66] Validation-avg_dice_coef_metric_floorplan=0.071930
# 2020-03-30 06:08:06,534 INFO - root - Epoch[67] Train-avg_dice_coef_metric_floorplan=0.016938
# 2020-03-30 06:08:06,534 INFO - root - Epoch[67] Time cost=1.653
# 2020-03-30 06:08:07,087 INFO - root - Epoch[67] Validation-avg_dice_coef_metric_floorplan=0.072963
# 2020-03-30 06:08:08,741 INFO - root - Epoch[68] Train-avg_dice_coef_metric_floorplan=0.015983
# 2020-03-30 06:08:08,741 INFO - root - Epoch[68] Time cost=1.653
# 2020-03-30 06:08:09,243 INFO - root - Epoch[68] Validation-avg_dice_coef_metric_floorplan=0.075791
# 2020-03-30 06:08:10,974 INFO - root - Epoch[69] Train-avg_dice_coef_metric_floorplan=0.015320
# 2020-03-30 06:08:10,974 INFO - root - Epoch[69] Time cost=1.731
# 2020-03-30 06:08:11,519 INFO - root - Epoch[69] Validation-avg_dice_coef_metric_floorplan=0.074496
# 2020-03-30 06:08:13,238 INFO - root - Epoch[70] Train-avg_dice_coef_metric_floorplan=0.015894
# 2020-03-30 06:08:13,238 INFO - root - Epoch[70] Time cost=1.719
# 2020-03-30 06:08:13,713 INFO - root - Epoch[70] Validation-avg_dice_coef_metric_floorplan=0.079117
# 2020-03-30 06:08:15,363 INFO - root - Epoch[71] Train-avg_dice_coef_metric_floorplan=0.016324
# 2020-03-30 06:08:15,363 INFO - root - Epoch[71] Time cost=1.650
# 2020-03-30 06:08:15,887 INFO - root - Epoch[71] Validation-avg_dice_coef_metric_floorplan=0.083304
# 2020-03-30 06:08:17,522 INFO - root - Epoch[72] Train-avg_dice_coef_metric_floorplan=0.017424
# 2020-03-30 06:08:17,522 INFO - root - Epoch[72] Time cost=1.635
# 2020-03-30 06:08:18,008 INFO - root - Epoch[72] Validation-avg_dice_coef_metric_floorplan=0.088219
# 2020-03-30 06:08:19,730 INFO - root - Epoch[73] Train-avg_dice_coef_metric_floorplan=0.019174
# 2020-03-30 06:08:19,730 INFO - root - Epoch[73] Time cost=1.722
# 2020-03-30 06:08:20,268 INFO - root - Epoch[73] Validation-avg_dice_coef_metric_floorplan=0.082281
# 2020-03-30 06:08:21,911 INFO - root - Epoch[74] Train-avg_dice_coef_metric_floorplan=0.020541
# 2020-03-30 06:08:21,912 INFO - root - Epoch[74] Time cost=1.643
# 2020-03-30 06:08:22,395 INFO - root - Epoch[74] Validation-avg_dice_coef_metric_floorplan=0.087613
# 2020-03-30 06:08:24,110 INFO - root - Epoch[75] Train-avg_dice_coef_metric_floorplan=0.021634
# 2020-03-30 06:08:24,110 INFO - root - Epoch[75] Time cost=1.714
# 2020-03-30 06:08:24,655 INFO - root - Epoch[75] Validation-avg_dice_coef_metric_floorplan=0.086261
# 2020-03-30 06:08:26,302 INFO - root - Epoch[76] Train-avg_dice_coef_metric_floorplan=0.024143
# 2020-03-30 06:08:26,302 INFO - root - Epoch[76] Time cost=1.647
# 2020-03-30 06:08:26,777 INFO - root - Epoch[76] Validation-avg_dice_coef_metric_floorplan=0.099462
# 2020-03-30 06:08:28,426 INFO - root - Epoch[77] Train-avg_dice_coef_metric_floorplan=0.026452
# 2020-03-30 06:08:28,426 INFO - root - Epoch[77] Time cost=1.649
# 2020-03-30 06:08:28,960 INFO - root - Epoch[77] Validation-avg_dice_coef_metric_floorplan=0.087557
# 2020-03-30 06:08:30,687 INFO - root - Epoch[78] Train-avg_dice_coef_metric_floorplan=0.027380
# 2020-03-30 06:08:30,687 INFO - root - Epoch[78] Time cost=1.727
# 2020-03-30 06:08:31,172 INFO - root - Epoch[78] Validation-avg_dice_coef_metric_floorplan=0.092185
# 2020-03-30 06:08:32,877 INFO - root - Epoch[79] Train-avg_dice_coef_metric_floorplan=0.023747
# 2020-03-30 06:08:32,878 INFO - root - Epoch[79] Time cost=1.705
# 2020-03-30 06:08:33,428 INFO - root - Epoch[79] Validation-avg_dice_coef_metric_floorplan=0.077412
# 2020-03-30 06:08:35,136 INFO - root - Epoch[80] Train-avg_dice_coef_metric_floorplan=0.022637
# 2020-03-30 06:08:35,136 INFO - root - Epoch[80] Time cost=1.708
# 2020-03-30 06:08:35,609 INFO - root - Epoch[80] Validation-avg_dice_coef_metric_floorplan=0.082139
# 2020-03-30 06:08:37,318 INFO - root - Epoch[81] Train-avg_dice_coef_metric_floorplan=0.020554
# 2020-03-30 06:08:37,318 INFO - root - Epoch[81] Time cost=1.709
# 2020-03-30 06:08:37,839 INFO - root - Epoch[81] Validation-avg_dice_coef_metric_floorplan=0.090408
# 2020-03-30 06:08:39,493 INFO - root - Epoch[82] Train-avg_dice_coef_metric_floorplan=0.021941
# 2020-03-30 06:08:39,494 INFO - root - Epoch[82] Time cost=1.654
# 2020-03-30 06:08:39,973 INFO - root - Epoch[82] Validation-avg_dice_coef_metric_floorplan=0.080814
# 2020-03-30 06:08:41,703 INFO - root - Epoch[83] Train-avg_dice_coef_metric_floorplan=0.020296
# 2020-03-30 06:08:41,703 INFO - root - Epoch[83] Time cost=1.730
# 2020-03-30 06:08:42,243 INFO - root - Epoch[83] Validation-avg_dice_coef_metric_floorplan=0.077666
# 2020-03-30 06:08:43,985 INFO - root - Epoch[84] Train-avg_dice_coef_metric_floorplan=0.017551
# 2020-03-30 06:08:43,986 INFO - root - Epoch[84] Time cost=1.742
# 2020-03-30 06:08:44,472 INFO - root - Epoch[84] Validation-avg_dice_coef_metric_floorplan=0.074570
# 2020-03-30 06:08:46,204 INFO - root - Epoch[85] Train-avg_dice_coef_metric_floorplan=0.016303
# 2020-03-30 06:08:46,205 INFO - root - Epoch[85] Time cost=1.732
# 2020-03-30 06:08:46,732 INFO - root - Epoch[85] Validation-avg_dice_coef_metric_floorplan=0.074105
# 2020-03-30 06:08:48,462 INFO - root - Epoch[86] Train-avg_dice_coef_metric_floorplan=0.016561
# 2020-03-30 06:08:48,462 INFO - root - Epoch[86] Time cost=1.730
# 2020-03-30 06:08:48,951 INFO - root - Epoch[86] Validation-avg_dice_coef_metric_floorplan=0.077080
# 2020-03-30 06:08:50,602 INFO - root - Epoch[87] Train-avg_dice_coef_metric_floorplan=0.015210
# 2020-03-30 06:08:50,603 INFO - root - Epoch[87] Time cost=1.651
# 2020-03-30 06:08:51,153 INFO - root - Epoch[87] Validation-avg_dice_coef_metric_floorplan=0.070914
# 2020-03-30 06:08:52,804 INFO - root - Epoch[88] Train-avg_dice_coef_metric_floorplan=0.014030
# 2020-03-30 06:08:52,804 INFO - root - Epoch[88] Time cost=1.651
# 2020-03-30 06:08:53,288 INFO - root - Epoch[88] Validation-avg_dice_coef_metric_floorplan=0.065036
# 2020-03-30 06:08:55,042 INFO - root - Epoch[89] Train-avg_dice_coef_metric_floorplan=0.013525
# 2020-03-30 06:08:55,042 INFO - root - Epoch[89] Time cost=1.754
# 2020-03-30 06:08:55,598 INFO - root - Epoch[89] Validation-avg_dice_coef_metric_floorplan=0.068123
# 2020-03-30 06:08:57,309 INFO - root - Epoch[90] Train-avg_dice_coef_metric_floorplan=0.012933
# 2020-03-30 06:08:57,309 INFO - root - Epoch[90] Time cost=1.710
# 2020-03-30 06:08:57,800 INFO - root - Epoch[90] Validation-avg_dice_coef_metric_floorplan=0.066227
# 2020-03-30 06:08:59,511 INFO - root - Epoch[91] Train-avg_dice_coef_metric_floorplan=0.012481
# 2020-03-30 06:08:59,512 INFO - root - Epoch[91] Time cost=1.711
# 2020-03-30 06:09:00,048 INFO - root - Epoch[91] Validation-avg_dice_coef_metric_floorplan=0.068867
# 2020-03-30 06:09:01,693 INFO - root - Epoch[92] Train-avg_dice_coef_metric_floorplan=0.012183
# 2020-03-30 06:09:01,693 INFO - root - Epoch[92] Time cost=1.645
# 2020-03-30 06:09:02,186 INFO - root - Epoch[92] Validation-avg_dice_coef_metric_floorplan=0.064641
# 2020-03-30 06:09:03,916 INFO - root - Epoch[93] Train-avg_dice_coef_metric_floorplan=0.011914
# 2020-03-30 06:09:03,917 INFO - root - Epoch[93] Time cost=1.730
# 2020-03-30 06:09:04,462 INFO - root - Epoch[93] Validation-avg_dice_coef_metric_floorplan=0.065168
# 2020-03-30 06:09:06,189 INFO - root - Epoch[94] Train-avg_dice_coef_metric_floorplan=0.011582
# 2020-03-30 06:09:06,190 INFO - root - Epoch[94] Time cost=1.727
# 2020-03-30 06:09:06,669 INFO - root - Epoch[94] Validation-avg_dice_coef_metric_floorplan=0.066662
# 2020-03-30 06:09:08,396 INFO - root - Epoch[95] Train-avg_dice_coef_metric_floorplan=0.011491
# 2020-03-30 06:09:08,397 INFO - root - Epoch[95] Time cost=1.724
# 2020-03-30 06:09:08,939 INFO - root - Epoch[95] Validation-avg_dice_coef_metric_floorplan=0.064675
# 2020-03-30 06:09:10,583 INFO - root - Epoch[96] Train-avg_dice_coef_metric_floorplan=0.011274
# 2020-03-30 06:09:10,584 INFO - root - Epoch[96] Time cost=1.645
# 2020-03-30 06:09:11,065 INFO - root - Epoch[96] Validation-avg_dice_coef_metric_floorplan=0.064923
# 2020-03-30 06:09:12,714 INFO - root - Epoch[97] Train-avg_dice_coef_metric_floorplan=0.011130
# 2020-03-30 06:09:12,714 INFO - root - Epoch[97] Time cost=1.649
# 2020-03-30 06:09:13,259 INFO - root - Epoch[97] Validation-avg_dice_coef_metric_floorplan=0.065794
# 2020-03-30 06:09:14,977 INFO - root - Epoch[98] Train-avg_dice_coef_metric_floorplan=0.010880
# 2020-03-30 06:09:14,978 INFO - root - Epoch[98] Time cost=1.718
# 2020-03-30 06:09:15,451 INFO - root - Epoch[98] Validation-avg_dice_coef_metric_floorplan=0.065600
# 2020-03-30 06:09:17,208 INFO - root - Epoch[99] Train-avg_dice_coef_metric_floorplan=0.011189
# 2020-03-30 06:09:17,208 INFO - root - Epoch[99] Time cost=1.757
# 2020-03-30 06:09:17,760 INFO - root - Epoch[99] Validation-avg_dice_coef_metric_floorplan=0.069393
#
# 2020-03-30 06:09:29 Uploading - Uploading generated training model
# 2020-03-30 06:09:29 Completed - Training job completed
# Training seconds: 296
# Billable seconds: 296

# %% [markdown]
# ### ENet
#
# Next, we'll train ENet.

# %%
enet_single_machine_job = 'cubicasa-enet-single-machine-job-' + \
    time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())

enet_single_machine_estimator = MXNet(entry_point='floorplan_segmentation.py',
                                      base_job_name=enet_single_machine_job,
                                      source_dir='source_dir',
                                      role=role,
                                      py_version='py3',
                                      train_instance_count=1,
                                      train_instance_type='ml.p3.2xlarge',
                                      hyperparameters={
                                          'learning_rate': 1E-3,
                                          'class_weights': [[1.35, 17.18]],
                                          'network': 'enet',
                                          'num_classes':2,
                                          'batch_size': 32,
                                      })

enet_single_machine_estimator.fit({'train': train_s3, 'test': validation_s3})
# Out:
# No framework_version specified, defaulting to version 1.2. This is not the latest supported version. If you would like to use version 1.6.0, please add framework_version=1.6.0 to your constructor.
# 2020-03-30 06:33:12 Starting - Starting the training job...
# 2020-03-30 06:33:14 Starting - Launching requested ML instances...
# 2020-03-30 06:34:12 Starting - Preparing the instances for training.........
# 2020-03-30 06:35:15 Downloading - Downloading input data...
# 2020-03-30 06:36:08 Training - Training image download completed. Training in progress..2020-03-30 06:36:08,752 INFO - root - running container entrypoint
# 2020-03-30 06:36:08,752 INFO - root - starting train task
# 2020-03-30 06:36:08,774 INFO - container_support.training - Training starting
# 2020-03-30 06:36:09,875 WARNING - mxnet_container.train - #033This required structure for training scripts will be deprecated with the next major release of MXNet images. The train() function will no longer be required; instead the training script must be able to be run as a standalone script. For more information, see https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/mxnet#updating-your-mxnet-training-script.#033
# 2020-03-30 06:36:09,890 INFO - mxnet_container.train - MXNetTrainingEnvironment: {'code_dir': '/opt/ml/code', 'user_script_archive': 's3://sagemaker-us-east-2-308537982265/cubicasa-enet-single-machine-job-2020-0-2020-03-30-06-33-12-346/source/sourcedir.tar.gz', 'input_dir': '/opt/ml/input', '_scheduler_host': 'algo-1', 'available_gpus': 1, 'job_name': 'cubicasa-enet-single-machine-job-2020-0-2020-03-30-06-33-12-346', 'channel_dirs': {'test': '/opt/ml/input/data/test', 'train': '/opt/ml/input/data/train'}, 'enable_cloudwatch_metrics': False, 'available_cpus': 8, 'input_config_dir': '/opt/ml/input/config', 'container_log_level': 20, 'hosts': ['algo-1'], 'base_dir': '/opt/ml', 'output_dir': '/opt/ml/output', 'hyperparameters': {'num_classes': 2, 'sagemaker_submit_directory': 's3://sagemaker-us-east-2-308537982265/cubicasa-enet-single-machine-job-2020-0-2020-03-30-06-33-12-346/source/sourcedir.tar.gz', 'sagemaker_region': 'us-east-2', 'sagemaker_program': 'floorplan_segmentation.py', 'batch_size': 32, 'network': 'enet', 'sagemaker_enable_cloudwatch_metrics': False, 'class_weights': [[1.35, 17.18]], 'sagemaker_container_log_level': 20, 'learning_rate': 0.001, 'sagemaker_job_name': 'cubicasa-enet-single-machine-job-2020-0-2020-03-30-06-33-12-346'}, '_ps_verbose': 0, '_ps_port': 8000, '_scheduler_ip': '10.0.124.182', 'channels': {'test': {'RecordWrapperType': 'None', 'S3DistributionType': 'FullyReplicated', 'TrainingInputMode': 'File'}, 'train': {'RecordWrapperType': 'None', 'S3DistributionType': 'FullyReplicated', 'TrainingInputMode': 'File'}}, 'user_script_name': 'floorplan_segmentation.py', 'sagemaker_region': 'us-east-2', 'current_host': 'algo-1', 'resource_config': {'network_interface_name': 'eth0', 'current_host': 'algo-1', 'hosts': ['algo-1']}, 'user_requirements_file': None, 'model_dir': '/opt/ml/model', 'output_data_dir': '/opt/ml/output/data/'}
# Downloading s3://sagemaker-us-east-2-308537982265/cubicasa-enet-single-machine-job-2020-0-2020-03-30-06-33-12-346/source/sourcedir.tar.gz to /tmp/script.tar.gz
# 2020-03-30 06:36:10,118 INFO - mxnet_container.train - Starting distributed training task
# /usr/local/lib/python3.5/dist-packages/mxnet_container/train.py:190: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   train_args = inspect.getargspec(user_module.train)
# 2020-03-30 06:36:10,137 INFO - root - 1.2.1
# 2020-03-30 06:36:10,437 INFO - root - Sym loaded
# 2020-03-30 06:36:10,441 INFO - root - Starting model fit
# [06:36:20] src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:107: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [06:36:21] src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:107: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# 2020-03-30 06:36:22,740 INFO - root - Epoch[0] Train-avg_dice_coef_metric_floorplan=0.450599
# 2020-03-30 06:36:22,740 INFO - root - Epoch[0] Time cost=2.176
# 2020-03-30 06:36:23,244 INFO - root - Epoch[0] Validation-avg_dice_coef_metric_floorplan=0.395966
# 2020-03-30 06:36:25,027 INFO - root - Epoch[1] Train-avg_dice_coef_metric_floorplan=0.358692
# 2020-03-30 06:36:25,027 INFO - root - Epoch[1] Time cost=1.783
# 2020-03-30 06:36:25,636 INFO - root - Epoch[1] Validation-avg_dice_coef_metric_floorplan=0.330127
# 2020-03-30 06:36:27,397 INFO - root - Epoch[2] Train-avg_dice_coef_metric_floorplan=0.293532
# 2020-03-30 06:36:27,397 INFO - root - Epoch[2] Time cost=1.761
# 2020-03-30 06:36:27,928 INFO - root - Epoch[2] Validation-avg_dice_coef_metric_floorplan=0.251869
# 2020-03-30 06:36:29,716 INFO - root - Epoch[3] Train-avg_dice_coef_metric_floorplan=0.243199
# 2020-03-30 06:36:29,716 INFO - root - Epoch[3] Time cost=1.788
# 2020-03-30 06:36:30,308 INFO - root - Epoch[3] Validation-avg_dice_coef_metric_floorplan=0.222167
# 2020-03-30 06:36:32,086 INFO - root - Epoch[4] Train-avg_dice_coef_metric_floorplan=0.198111
# 2020-03-30 06:36:32,086 INFO - root - Epoch[4] Time cost=1.778
# 2020-03-30 06:36:32,601 INFO - root - Epoch[4] Validation-avg_dice_coef_metric_floorplan=0.186901
# 2020-03-30 06:36:34,365 INFO - root - Epoch[5] Train-avg_dice_coef_metric_floorplan=0.164970
# 2020-03-30 06:36:34,365 INFO - root - Epoch[5] Time cost=1.763
# 2020-03-30 06:36:34,954 INFO - root - Epoch[5] Validation-avg_dice_coef_metric_floorplan=0.176983
# 2020-03-30 06:36:36,669 INFO - root - Epoch[6] Train-avg_dice_coef_metric_floorplan=0.142783
# 2020-03-30 06:36:36,670 INFO - root - Epoch[6] Time cost=1.715
# 2020-03-30 06:36:37,181 INFO - root - Epoch[6] Validation-avg_dice_coef_metric_floorplan=0.143264
# 2020-03-30 06:36:38,902 INFO - root - Epoch[7] Train-avg_dice_coef_metric_floorplan=0.124231
# 2020-03-30 06:36:38,902 INFO - root - Epoch[7] Time cost=1.721
# 2020-03-30 06:36:39,474 INFO - root - Epoch[7] Validation-avg_dice_coef_metric_floorplan=0.145658
# 2020-03-30 06:36:41,217 INFO - root - Epoch[8] Train-avg_dice_coef_metric_floorplan=0.109304
# 2020-03-30 06:36:41,217 INFO - root - Epoch[8] Time cost=1.743
# 2020-03-30 06:36:41,752 INFO - root - Epoch[8] Validation-avg_dice_coef_metric_floorplan=0.127499
# 2020-03-30 06:36:43,441 INFO - root - Epoch[9] Train-avg_dice_coef_metric_floorplan=0.098185
# 2020-03-30 06:36:43,441 INFO - root - Epoch[9] Time cost=1.689
# 2020-03-30 06:36:44,027 INFO - root - Epoch[9] Validation-avg_dice_coef_metric_floorplan=0.125054
# 2020-03-30 06:36:45,741 INFO - root - Epoch[10] Train-avg_dice_coef_metric_floorplan=0.090686
# 2020-03-30 06:36:45,741 INFO - root - Epoch[10] Time cost=1.714
# 2020-03-30 06:36:46,263 INFO - root - Epoch[10] Validation-avg_dice_coef_metric_floorplan=0.119573
# 2020-03-30 06:36:47,993 INFO - root - Epoch[11] Train-avg_dice_coef_metric_floorplan=0.080543
# 2020-03-30 06:36:47,993 INFO - root - Epoch[11] Time cost=1.730
# 2020-03-30 06:36:48,589 INFO - root - Epoch[11] Validation-avg_dice_coef_metric_floorplan=0.114845
# 2020-03-30 06:36:50,316 INFO - root - Epoch[12] Train-avg_dice_coef_metric_floorplan=0.075972
# 2020-03-30 06:36:50,316 INFO - root - Epoch[12] Time cost=1.727
# 2020-03-30 06:36:50,824 INFO - root - Epoch[12] Validation-avg_dice_coef_metric_floorplan=0.108389
# 2020-03-30 06:36:52,614 INFO - root - Epoch[13] Train-avg_dice_coef_metric_floorplan=0.067598
# 2020-03-30 06:36:52,615 INFO - root - Epoch[13] Time cost=1.791
# 2020-03-30 06:36:53,181 INFO - root - Epoch[13] Validation-avg_dice_coef_metric_floorplan=0.111902
# 2020-03-30 06:36:54,954 INFO - root - Epoch[14] Train-avg_dice_coef_metric_floorplan=0.061144
# 2020-03-30 06:36:54,954 INFO - root - Epoch[14] Time cost=1.773
# 2020-03-30 06:36:55,485 INFO - root - Epoch[14] Validation-avg_dice_coef_metric_floorplan=0.098760
# 2020-03-30 06:36:57,195 INFO - root - Epoch[15] Train-avg_dice_coef_metric_floorplan=0.058721
# 2020-03-30 06:36:57,196 INFO - root - Epoch[15] Time cost=1.710
# 2020-03-30 06:36:57,784 INFO - root - Epoch[15] Validation-avg_dice_coef_metric_floorplan=0.105588
# 2020-03-30 06:36:59,553 INFO - root - Epoch[16] Train-avg_dice_coef_metric_floorplan=0.056542
# 2020-03-30 06:36:59,553 INFO - root - Epoch[16] Time cost=1.768
# 2020-03-30 06:37:00,069 INFO - root - Epoch[16] Validation-avg_dice_coef_metric_floorplan=0.099675
# 2020-03-30 06:37:01,870 INFO - root - Epoch[17] Train-avg_dice_coef_metric_floorplan=0.053497
# 2020-03-30 06:37:01,871 INFO - root - Epoch[17] Time cost=1.802
# 2020-03-30 06:37:02,451 INFO - root - Epoch[17] Validation-avg_dice_coef_metric_floorplan=0.101056
# 2020-03-30 06:37:04,218 INFO - root - Epoch[18] Train-avg_dice_coef_metric_floorplan=0.050217
# 2020-03-30 06:37:04,219 INFO - root - Epoch[18] Time cost=1.768
# 2020-03-30 06:37:04,761 INFO - root - Epoch[18] Validation-avg_dice_coef_metric_floorplan=0.098720
# 2020-03-30 06:37:06,452 INFO - root - Epoch[19] Train-avg_dice_coef_metric_floorplan=0.052270
# 2020-03-30 06:37:06,452 INFO - root - Epoch[19] Time cost=1.690
# 2020-03-30 06:37:07,040 INFO - root - Epoch[19] Validation-avg_dice_coef_metric_floorplan=0.105047
# 2020-03-30 06:37:08,805 INFO - root - Epoch[20] Train-avg_dice_coef_metric_floorplan=0.050788
# 2020-03-30 06:37:08,805 INFO - root - Epoch[20] Time cost=1.765
# 2020-03-30 06:37:09,331 INFO - root - Epoch[20] Validation-avg_dice_coef_metric_floorplan=0.103523
# 2020-03-30 06:37:11,096 INFO - root - Epoch[21] Train-avg_dice_coef_metric_floorplan=0.052847
# 2020-03-30 06:37:11,097 INFO - root - Epoch[21] Time cost=1.765
# 2020-03-30 06:37:11,679 INFO - root - Epoch[21] Validation-avg_dice_coef_metric_floorplan=0.117621
# 2020-03-30 06:37:13,384 INFO - root - Epoch[22] Train-avg_dice_coef_metric_floorplan=0.050646
# 2020-03-30 06:37:13,384 INFO - root - Epoch[22] Time cost=1.704
# 2020-03-30 06:37:13,896 INFO - root - Epoch[22] Validation-avg_dice_coef_metric_floorplan=0.102986
# 2020-03-30 06:37:15,695 INFO - root - Epoch[23] Train-avg_dice_coef_metric_floorplan=0.045828
# 2020-03-30 06:37:15,695 INFO - root - Epoch[23] Time cost=1.799
# 2020-03-30 06:37:16,287 INFO - root - Epoch[23] Validation-avg_dice_coef_metric_floorplan=0.100571
# 2020-03-30 06:37:17,980 INFO - root - Epoch[24] Train-avg_dice_coef_metric_floorplan=0.043443
# 2020-03-30 06:37:17,981 INFO - root - Epoch[24] Time cost=1.694
# 2020-03-30 06:37:18,504 INFO - root - Epoch[24] Validation-avg_dice_coef_metric_floorplan=0.096777
# 2020-03-30 06:37:20,228 INFO - root - Epoch[25] Train-avg_dice_coef_metric_floorplan=0.041831
# 2020-03-30 06:37:20,228 INFO - root - Epoch[25] Time cost=1.724
# 2020-03-30 06:37:20,801 INFO - root - Epoch[25] Validation-avg_dice_coef_metric_floorplan=0.099995
# 2020-03-30 06:37:22,567 INFO - root - Epoch[26] Train-avg_dice_coef_metric_floorplan=0.039255
# 2020-03-30 06:37:22,568 INFO - root - Epoch[26] Time cost=1.766
# 2020-03-30 06:37:23,105 INFO - root - Epoch[26] Validation-avg_dice_coef_metric_floorplan=0.096847
# 2020-03-30 06:37:24,891 INFO - root - Epoch[27] Train-avg_dice_coef_metric_floorplan=0.036108
# 2020-03-30 06:37:24,891 INFO - root - Epoch[27] Time cost=1.786
# 2020-03-30 06:37:25,471 INFO - root - Epoch[27] Validation-avg_dice_coef_metric_floorplan=0.101275
# 2020-03-30 06:37:27,257 INFO - root - Epoch[28] Train-avg_dice_coef_metric_floorplan=0.035053
# 2020-03-30 06:37:27,258 INFO - root - Epoch[28] Time cost=1.787
# 2020-03-30 06:37:27,769 INFO - root - Epoch[28] Validation-avg_dice_coef_metric_floorplan=0.086983
# 2020-03-30 06:37:29,502 INFO - root - Epoch[29] Train-avg_dice_coef_metric_floorplan=0.036259
# 2020-03-30 06:37:29,503 INFO - root - Epoch[29] Time cost=1.733
# 2020-03-30 06:37:30,094 INFO - root - Epoch[29] Validation-avg_dice_coef_metric_floorplan=0.100040
# 2020-03-30 06:37:31,859 INFO - root - Epoch[30] Train-avg_dice_coef_metric_floorplan=0.035137
# 2020-03-30 06:37:31,860 INFO - root - Epoch[30] Time cost=1.765
# 2020-03-30 06:37:32,397 INFO - root - Epoch[30] Validation-avg_dice_coef_metric_floorplan=0.087039
# 2020-03-30 06:37:34,172 INFO - root - Epoch[31] Train-avg_dice_coef_metric_floorplan=0.037219
# 2020-03-30 06:37:34,172 INFO - root - Epoch[31] Time cost=1.775
# 2020-03-30 06:37:34,757 INFO - root - Epoch[31] Validation-avg_dice_coef_metric_floorplan=0.115568
# 2020-03-30 06:37:36,532 INFO - root - Epoch[32] Train-avg_dice_coef_metric_floorplan=0.036610
# 2020-03-30 06:37:36,532 INFO - root - Epoch[32] Time cost=1.775
# 2020-03-30 06:37:37,050 INFO - root - Epoch[32] Validation-avg_dice_coef_metric_floorplan=0.091085
# 2020-03-30 06:37:38,788 INFO - root - Epoch[33] Train-avg_dice_coef_metric_floorplan=0.035135
# 2020-03-30 06:37:38,788 INFO - root - Epoch[33] Time cost=1.737
# 2020-03-30 06:37:39,372 INFO - root - Epoch[33] Validation-avg_dice_coef_metric_floorplan=0.104063
# 2020-03-30 06:37:41,139 INFO - root - Epoch[34] Train-avg_dice_coef_metric_floorplan=0.031418
# 2020-03-30 06:37:41,139 INFO - root - Epoch[34] Time cost=1.766
# 2020-03-30 06:37:41,667 INFO - root - Epoch[34] Validation-avg_dice_coef_metric_floorplan=0.084750
# 2020-03-30 06:37:43,433 INFO - root - Epoch[35] Train-avg_dice_coef_metric_floorplan=0.030710
# 2020-03-30 06:37:43,433 INFO - root - Epoch[35] Time cost=1.766
# 2020-03-30 06:37:44,022 INFO - root - Epoch[35] Validation-avg_dice_coef_metric_floorplan=0.097242
# 2020-03-30 06:37:45,802 INFO - root - Epoch[36] Train-avg_dice_coef_metric_floorplan=0.028380
# 2020-03-30 06:37:45,802 INFO - root - Epoch[36] Time cost=1.779
# 2020-03-30 06:37:46,308 INFO - root - Epoch[36] Validation-avg_dice_coef_metric_floorplan=0.091037
# 2020-03-30 06:37:48,058 INFO - root - Epoch[37] Train-avg_dice_coef_metric_floorplan=0.028758
# 2020-03-30 06:37:48,059 INFO - root - Epoch[37] Time cost=1.751
# 2020-03-30 06:37:48,651 INFO - root - Epoch[37] Validation-avg_dice_coef_metric_floorplan=0.109319
# 2020-03-30 06:37:50,344 INFO - root - Epoch[38] Train-avg_dice_coef_metric_floorplan=0.029983
# 2020-03-30 06:37:50,344 INFO - root - Epoch[38] Time cost=1.694
# 2020-03-30 06:37:50,885 INFO - root - Epoch[38] Validation-avg_dice_coef_metric_floorplan=0.087664
# 2020-03-30 06:37:52,664 INFO - root - Epoch[39] Train-avg_dice_coef_metric_floorplan=0.027495
# 2020-03-30 06:37:52,664 INFO - root - Epoch[39] Time cost=1.779
# 2020-03-30 06:37:53,228 INFO - root - Epoch[39] Validation-avg_dice_coef_metric_floorplan=0.094242
# 2020-03-30 06:37:54,964 INFO - root - Epoch[40] Train-avg_dice_coef_metric_floorplan=0.026349
# 2020-03-30 06:37:54,964 INFO - root - Epoch[40] Time cost=1.735
# 2020-03-30 06:37:55,485 INFO - root - Epoch[40] Validation-avg_dice_coef_metric_floorplan=0.083441
# 2020-03-30 06:37:57,231 INFO - root - Epoch[41] Train-avg_dice_coef_metric_floorplan=0.025467
# 2020-03-30 06:37:57,231 INFO - root - Epoch[41] Time cost=1.745
# 2020-03-30 06:37:57,797 INFO - root - Epoch[41] Validation-avg_dice_coef_metric_floorplan=0.101986
# 2020-03-30 06:37:59,505 INFO - root - Epoch[42] Train-avg_dice_coef_metric_floorplan=0.024950
# 2020-03-30 06:37:59,505 INFO - root - Epoch[42] Time cost=1.708
# 2020-03-30 06:38:00,025 INFO - root - Epoch[42] Validation-avg_dice_coef_metric_floorplan=0.090452
# 2020-03-30 06:38:01,779 INFO - root - Epoch[43] Train-avg_dice_coef_metric_floorplan=0.024699
# 2020-03-30 06:38:01,779 INFO - root - Epoch[43] Time cost=1.753
# 2020-03-30 06:38:02,361 INFO - root - Epoch[43] Validation-avg_dice_coef_metric_floorplan=0.100005
# 2020-03-30 06:38:04,124 INFO - root - Epoch[44] Train-avg_dice_coef_metric_floorplan=0.024373
# 2020-03-30 06:38:04,124 INFO - root - Epoch[44] Time cost=1.763
# 2020-03-30 06:38:04,655 INFO - root - Epoch[44] Validation-avg_dice_coef_metric_floorplan=0.083535
# 2020-03-30 06:38:06,380 INFO - root - Epoch[45] Train-avg_dice_coef_metric_floorplan=0.022890
# 2020-03-30 06:38:06,380 INFO - root - Epoch[45] Time cost=1.725
# 2020-03-30 06:38:06,969 INFO - root - Epoch[45] Validation-avg_dice_coef_metric_floorplan=0.095848
# 2020-03-30 06:38:08,753 INFO - root - Epoch[46] Train-avg_dice_coef_metric_floorplan=0.022890
# 2020-03-30 06:38:08,753 INFO - root - Epoch[46] Time cost=1.784
# 2020-03-30 06:38:09,277 INFO - root - Epoch[46] Validation-avg_dice_coef_metric_floorplan=0.084390
# 2020-03-30 06:38:11,052 INFO - root - Epoch[47] Train-avg_dice_coef_metric_floorplan=0.022458
# 2020-03-30 06:38:11,052 INFO - root - Epoch[47] Time cost=1.775
# 2020-03-30 06:38:11,642 INFO - root - Epoch[47] Validation-avg_dice_coef_metric_floorplan=0.097873
# 2020-03-30 06:38:13,410 INFO - root - Epoch[48] Train-avg_dice_coef_metric_floorplan=0.021887
# 2020-03-30 06:38:13,411 INFO - root - Epoch[48] Time cost=1.768
# 2020-03-30 06:38:13,927 INFO - root - Epoch[48] Validation-avg_dice_coef_metric_floorplan=0.086017
# 2020-03-30 06:38:15,650 INFO - root - Epoch[49] Train-avg_dice_coef_metric_floorplan=0.021684
# 2020-03-30 06:38:15,650 INFO - root - Epoch[49] Time cost=1.722
# 2020-03-30 06:38:16,234 INFO - root - Epoch[49] Validation-avg_dice_coef_metric_floorplan=0.096910
# 2020-03-30 06:38:18,014 INFO - root - Epoch[50] Train-avg_dice_coef_metric_floorplan=0.020566
# 2020-03-30 06:38:18,014 INFO - root - Epoch[50] Time cost=1.780
# 2020-03-30 06:38:18,546 INFO - root - Epoch[50] Validation-avg_dice_coef_metric_floorplan=0.083091
# 2020-03-30 06:38:20,317 INFO - root - Epoch[51] Train-avg_dice_coef_metric_floorplan=0.019804
# 2020-03-30 06:38:20,317 INFO - root - Epoch[51] Time cost=1.771
# 2020-03-30 06:38:20,897 INFO - root - Epoch[51] Validation-avg_dice_coef_metric_floorplan=0.090589
# 2020-03-30 06:38:22,660 INFO - root - Epoch[52] Train-avg_dice_coef_metric_floorplan=0.019907
# 2020-03-30 06:38:22,661 INFO - root - Epoch[52] Time cost=1.764
# 2020-03-30 06:38:23,196 INFO - root - Epoch[52] Validation-avg_dice_coef_metric_floorplan=0.080145
# 2020-03-30 06:38:24,931 INFO - root - Epoch[53] Train-avg_dice_coef_metric_floorplan=0.019141
# 2020-03-30 06:38:24,931 INFO - root - Epoch[53] Time cost=1.734
# 2020-03-30 06:38:25,522 INFO - root - Epoch[53] Validation-avg_dice_coef_metric_floorplan=0.093213
# 2020-03-30 06:38:27,306 INFO - root - Epoch[54] Train-avg_dice_coef_metric_floorplan=0.020141
# 2020-03-30 06:38:27,306 INFO - root - Epoch[54] Time cost=1.784
# 2020-03-30 06:38:27,824 INFO - root - Epoch[54] Validation-avg_dice_coef_metric_floorplan=0.084868
# 2020-03-30 06:38:29,516 INFO - root - Epoch[55] Train-avg_dice_coef_metric_floorplan=0.023268
# 2020-03-30 06:38:29,516 INFO - root - Epoch[55] Time cost=1.692
# 2020-03-30 06:38:30,098 INFO - root - Epoch[55] Validation-avg_dice_coef_metric_floorplan=0.102677
# 2020-03-30 06:38:31,878 INFO - root - Epoch[56] Train-avg_dice_coef_metric_floorplan=0.026080
# 2020-03-30 06:38:31,879 INFO - root - Epoch[56] Time cost=1.780
# 2020-03-30 06:38:32,402 INFO - root - Epoch[56] Validation-avg_dice_coef_metric_floorplan=0.083901
# 2020-03-30 06:38:34,163 INFO - root - Epoch[57] Train-avg_dice_coef_metric_floorplan=0.025754
# 2020-03-30 06:38:34,164 INFO - root - Epoch[57] Time cost=1.761
# 2020-03-30 06:38:34,721 INFO - root - Epoch[57] Validation-avg_dice_coef_metric_floorplan=0.098067
# 2020-03-30 06:38:36,485 INFO - root - Epoch[58] Train-avg_dice_coef_metric_floorplan=0.023188
# 2020-03-30 06:38:36,486 INFO - root - Epoch[58] Time cost=1.765
# 2020-03-30 06:38:37,032 INFO - root - Epoch[58] Validation-avg_dice_coef_metric_floorplan=0.084389
# 2020-03-30 06:38:38,813 INFO - root - Epoch[59] Train-avg_dice_coef_metric_floorplan=0.022593
# 2020-03-30 06:38:38,813 INFO - root - Epoch[59] Time cost=1.781
# 2020-03-30 06:38:39,408 INFO - root - Epoch[59] Validation-avg_dice_coef_metric_floorplan=0.090720
# 2020-03-30 06:38:41,162 INFO - root - Epoch[60] Train-avg_dice_coef_metric_floorplan=0.020215
# 2020-03-30 06:38:41,163 INFO - root - Epoch[60] Time cost=1.755
# 2020-03-30 06:38:41,703 INFO - root - Epoch[60] Validation-avg_dice_coef_metric_floorplan=0.078810
# 2020-03-30 06:38:43,418 INFO - root - Epoch[61] Train-avg_dice_coef_metric_floorplan=0.020529
# 2020-03-30 06:38:43,419 INFO - root - Epoch[61] Time cost=1.715
# 2020-03-30 06:38:44,010 INFO - root - Epoch[61] Validation-avg_dice_coef_metric_floorplan=0.090523
# 2020-03-30 06:38:45,766 INFO - root - Epoch[62] Train-avg_dice_coef_metric_floorplan=0.019768
# 2020-03-30 06:38:45,766 INFO - root - Epoch[62] Time cost=1.756
# 2020-03-30 06:38:46,273 INFO - root - Epoch[62] Validation-avg_dice_coef_metric_floorplan=0.081836
# 2020-03-30 06:38:48,044 INFO - root - Epoch[63] Train-avg_dice_coef_metric_floorplan=0.020332
# 2020-03-30 06:38:48,044 INFO - root - Epoch[63] Time cost=1.770
# 2020-03-30 06:38:48,632 INFO - root - Epoch[63] Validation-avg_dice_coef_metric_floorplan=0.085081
# 2020-03-30 06:38:50,405 INFO - root - Epoch[64] Train-avg_dice_coef_metric_floorplan=0.018692
# 2020-03-30 06:38:50,405 INFO - root - Epoch[64] Time cost=1.773
# 2020-03-30 06:38:50,954 INFO - root - Epoch[64] Validation-avg_dice_coef_metric_floorplan=0.077850
# 2020-03-30 06:38:52,659 INFO - root - Epoch[65] Train-avg_dice_coef_metric_floorplan=0.019120
# 2020-03-30 06:38:52,660 INFO - root - Epoch[65] Time cost=1.705
# 2020-03-30 06:38:53,243 INFO - root - Epoch[65] Validation-avg_dice_coef_metric_floorplan=0.087267
# 2020-03-30 06:38:54,962 INFO - root - Epoch[66] Train-avg_dice_coef_metric_floorplan=0.021336
# 2020-03-30 06:38:54,962 INFO - root - Epoch[66] Time cost=1.719
# 2020-03-30 06:38:55,518 INFO - root - Epoch[66] Validation-avg_dice_coef_metric_floorplan=0.083600
# 2020-03-30 06:38:57,312 INFO - root - Epoch[67] Train-avg_dice_coef_metric_floorplan=0.022812
# 2020-03-30 06:38:57,312 INFO - root - Epoch[67] Time cost=1.793
# 2020-03-30 06:38:57,894 INFO - root - Epoch[67] Validation-avg_dice_coef_metric_floorplan=0.096518
# 2020-03-30 06:38:59,606 INFO - root - Epoch[68] Train-avg_dice_coef_metric_floorplan=0.021457
# 2020-03-30 06:38:59,606 INFO - root - Epoch[68] Time cost=1.712
# 2020-03-30 06:39:00,116 INFO - root - Epoch[68] Validation-avg_dice_coef_metric_floorplan=0.079359
# 2020-03-30 06:39:01,845 INFO - root - Epoch[69] Train-avg_dice_coef_metric_floorplan=0.020597
# 2020-03-30 06:39:01,845 INFO - root - Epoch[69] Time cost=1.725
# 2020-03-30 06:39:02,436 INFO - root - Epoch[69] Validation-avg_dice_coef_metric_floorplan=0.094843
# 2020-03-30 06:39:04,208 INFO - root - Epoch[70] Train-avg_dice_coef_metric_floorplan=0.018486
# 2020-03-30 06:39:04,209 INFO - root - Epoch[70] Time cost=1.772
# 2020-03-30 06:39:04,762 INFO - root - Epoch[70] Validation-avg_dice_coef_metric_floorplan=0.083873
# 2020-03-30 06:39:06,526 INFO - root - Epoch[71] Train-avg_dice_coef_metric_floorplan=0.022363
# 2020-03-30 06:39:06,527 INFO - root - Epoch[71] Time cost=1.764
# 2020-03-30 06:39:07,105 INFO - root - Epoch[71] Validation-avg_dice_coef_metric_floorplan=0.100563
# 2020-03-30 06:39:08,813 INFO - root - Epoch[72] Train-avg_dice_coef_metric_floorplan=0.020110
# 2020-03-30 06:39:08,814 INFO - root - Epoch[72] Time cost=1.708
# 2020-03-30 06:39:09,344 INFO - root - Epoch[72] Validation-avg_dice_coef_metric_floorplan=0.083660
# 2020-03-30 06:39:11,068 INFO - root - Epoch[73] Train-avg_dice_coef_metric_floorplan=0.018283
# 2020-03-30 06:39:11,068 INFO - root - Epoch[73] Time cost=1.723
# 2020-03-30 06:39:11,656 INFO - root - Epoch[73] Validation-avg_dice_coef_metric_floorplan=0.094115
# 2020-03-30 06:39:13,372 INFO - root - Epoch[74] Train-avg_dice_coef_metric_floorplan=0.017127
# 2020-03-30 06:39:13,372 INFO - root - Epoch[74] Time cost=1.715
# 2020-03-30 06:39:13,899 INFO - root - Epoch[74] Validation-avg_dice_coef_metric_floorplan=0.081790
# 2020-03-30 06:39:15,683 INFO - root - Epoch[75] Train-avg_dice_coef_metric_floorplan=0.016888
# 2020-03-30 06:39:15,683 INFO - root - Epoch[75] Time cost=1.784
# 2020-03-30 06:39:16,279 INFO - root - Epoch[75] Validation-avg_dice_coef_metric_floorplan=0.089744
# 2020-03-30 06:39:18,044 INFO - root - Epoch[76] Train-avg_dice_coef_metric_floorplan=0.016964
# 2020-03-30 06:39:18,045 INFO - root - Epoch[76] Time cost=1.765
# 2020-03-30 06:39:18,591 INFO - root - Epoch[76] Validation-avg_dice_coef_metric_floorplan=0.088760
# 2020-03-30 06:39:20,387 INFO - root - Epoch[77] Train-avg_dice_coef_metric_floorplan=0.015508
# 2020-03-30 06:39:20,387 INFO - root - Epoch[77] Time cost=1.796
# 2020-03-30 06:39:20,972 INFO - root - Epoch[77] Validation-avg_dice_coef_metric_floorplan=0.095094
# 2020-03-30 06:39:22,733 INFO - root - Epoch[78] Train-avg_dice_coef_metric_floorplan=0.014710
# 2020-03-30 06:39:22,733 INFO - root - Epoch[78] Time cost=1.761
# 2020-03-30 06:39:23,247 INFO - root - Epoch[78] Validation-avg_dice_coef_metric_floorplan=0.081962
# 2020-03-30 06:39:25,010 INFO - root - Epoch[79] Train-avg_dice_coef_metric_floorplan=0.013848
# 2020-03-30 06:39:25,010 INFO - root - Epoch[79] Time cost=1.763
# 2020-03-30 06:39:25,640 INFO - root - Epoch[79] Validation-avg_dice_coef_metric_floorplan=0.091994
# 2020-03-30 06:39:27,438 INFO - root - Epoch[80] Train-avg_dice_coef_metric_floorplan=0.013563
# 2020-03-30 06:39:27,438 INFO - root - Epoch[80] Time cost=1.798
# 2020-03-30 06:39:27,941 INFO - root - Epoch[80] Validation-avg_dice_coef_metric_floorplan=0.086709
# 2020-03-30 06:39:29,708 INFO - root - Epoch[81] Train-avg_dice_coef_metric_floorplan=0.013051
# 2020-03-30 06:39:29,708 INFO - root - Epoch[81] Time cost=1.766
# 2020-03-30 06:39:30,298 INFO - root - Epoch[81] Validation-avg_dice_coef_metric_floorplan=0.090980
# 2020-03-30 06:39:32,070 INFO - root - Epoch[82] Train-avg_dice_coef_metric_floorplan=0.013287
# 2020-03-30 06:39:32,070 INFO - root - Epoch[82] Time cost=1.772
# 2020-03-30 06:39:32,600 INFO - root - Epoch[82] Validation-avg_dice_coef_metric_floorplan=0.079568
# 2020-03-30 06:39:34,380 INFO - root - Epoch[83] Train-avg_dice_coef_metric_floorplan=0.013481
# 2020-03-30 06:39:34,380 INFO - root - Epoch[83] Time cost=1.780
# 2020-03-30 06:39:34,972 INFO - root - Epoch[83] Validation-avg_dice_coef_metric_floorplan=0.089433
# 2020-03-30 06:39:36,752 INFO - root - Epoch[84] Train-avg_dice_coef_metric_floorplan=0.015016
# 2020-03-30 06:39:36,752 INFO - root - Epoch[84] Time cost=1.779
# 2020-03-30 06:39:37,282 INFO - root - Epoch[84] Validation-avg_dice_coef_metric_floorplan=0.083565
# 2020-03-30 06:39:39,042 INFO - root - Epoch[85] Train-avg_dice_coef_metric_floorplan=0.015062
# 2020-03-30 06:39:39,042 INFO - root - Epoch[85] Time cost=1.759
# 2020-03-30 06:39:39,639 INFO - root - Epoch[85] Validation-avg_dice_coef_metric_floorplan=0.094012
# 2020-03-30 06:39:41,426 INFO - root - Epoch[86] Train-avg_dice_coef_metric_floorplan=0.016522
# 2020-03-30 06:39:41,426 INFO - root - Epoch[86] Time cost=1.787
# 2020-03-30 06:39:41,980 INFO - root - Epoch[86] Validation-avg_dice_coef_metric_floorplan=0.085580
# 2020-03-30 06:39:43,733 INFO - root - Epoch[87] Train-avg_dice_coef_metric_floorplan=0.017052
# 2020-03-30 06:39:43,733 INFO - root - Epoch[87] Time cost=1.753
# 2020-03-30 06:39:44,310 INFO - root - Epoch[87] Validation-avg_dice_coef_metric_floorplan=0.108501
# 2020-03-30 06:39:46,055 INFO - root - Epoch[88] Train-avg_dice_coef_metric_floorplan=0.016091
# 2020-03-30 06:39:46,056 INFO - root - Epoch[88] Time cost=1.746
# 2020-03-30 06:39:46,585 INFO - root - Epoch[88] Validation-avg_dice_coef_metric_floorplan=0.093917
# 2020-03-30 06:39:48,276 INFO - root - Epoch[89] Train-avg_dice_coef_metric_floorplan=0.015147
# 2020-03-30 06:39:48,276 INFO - root - Epoch[89] Time cost=1.691
# 2020-03-30 06:39:48,859 INFO - root - Epoch[89] Validation-avg_dice_coef_metric_floorplan=0.097194
# 2020-03-30 06:39:50,621 INFO - root - Epoch[90] Train-avg_dice_coef_metric_floorplan=0.016094
# 2020-03-30 06:39:50,622 INFO - root - Epoch[90] Time cost=1.762
# 2020-03-30 06:39:51,128 INFO - root - Epoch[90] Validation-avg_dice_coef_metric_floorplan=0.083345
# 2020-03-30 06:39:52,868 INFO - root - Epoch[91] Train-avg_dice_coef_metric_floorplan=0.013833
# 2020-03-30 06:39:52,868 INFO - root - Epoch[91] Time cost=1.740
# 2020-03-30 06:39:53,463 INFO - root - Epoch[91] Validation-avg_dice_coef_metric_floorplan=0.085701
# 2020-03-30 06:39:55,197 INFO - root - Epoch[92] Train-avg_dice_coef_metric_floorplan=0.012277
# 2020-03-30 06:39:55,198 INFO - root - Epoch[92] Time cost=1.734
# 2020-03-30 06:39:55,735 INFO - root - Epoch[92] Validation-avg_dice_coef_metric_floorplan=0.080435
# 2020-03-30 06:39:57,525 INFO - root - Epoch[93] Train-avg_dice_coef_metric_floorplan=0.011396
# 2020-03-30 06:39:57,525 INFO - root - Epoch[93] Time cost=1.789
# 2020-03-30 06:39:58,112 INFO - root - Epoch[93] Validation-avg_dice_coef_metric_floorplan=0.084719
# 2020-03-30 06:39:59,835 INFO - root - Epoch[94] Train-avg_dice_coef_metric_floorplan=0.011552
# 2020-03-30 06:39:59,836 INFO - root - Epoch[94] Time cost=1.724
# 2020-03-30 06:40:00,351 INFO - root - Epoch[94] Validation-avg_dice_coef_metric_floorplan=0.076759
# 2020-03-30 06:40:02,112 INFO - root - Epoch[95] Train-avg_dice_coef_metric_floorplan=0.011074
# 2020-03-30 06:40:02,112 INFO - root - Epoch[95] Time cost=1.761
# 2020-03-30 06:40:02,687 INFO - root - Epoch[95] Validation-avg_dice_coef_metric_floorplan=0.082883
# 2020-03-30 06:40:04,406 INFO - root - Epoch[96] Train-avg_dice_coef_metric_floorplan=0.010868
# 2020-03-30 06:40:04,407 INFO - root - Epoch[96] Time cost=1.719
# 2020-03-30 06:40:04,936 INFO - root - Epoch[96] Validation-avg_dice_coef_metric_floorplan=0.085989
# 2020-03-30 06:40:06,719 INFO - root - Epoch[97] Train-avg_dice_coef_metric_floorplan=0.010543
# 2020-03-30 06:40:06,719 INFO - root - Epoch[97] Time cost=1.783
# 2020-03-30 06:40:07,273 INFO - root - Epoch[97] Validation-avg_dice_coef_metric_floorplan=0.085246
# 2020-03-30 06:40:09,055 INFO - root - Epoch[98] Train-avg_dice_coef_metric_floorplan=0.009633
# 2020-03-30 06:40:09,055 INFO - root - Epoch[98] Time cost=1.781
# 2020-03-30 06:40:09,565 INFO - root - Epoch[98] Validation-avg_dice_coef_metric_floorplan=0.080065
# 2020-03-30 06:40:11,322 INFO - root - Epoch[99] Train-avg_dice_coef_metric_floorplan=0.009254
# 2020-03-30 06:40:11,323 INFO - root - Epoch[99] Time cost=1.758
# 2020-03-30 06:40:11,945 INFO - root - Epoch[99] Validation-avg_dice_coef_metric_floorplan=0.086213
#
# 2020-03-30 06:41:11 Uploading - Uploading generated training model
# 2020-03-30 06:41:18 Completed - Training job completed
# Training seconds: 363
# Billable seconds: 363

# %% [markdown]
# ## Inference Endpoints
#
# Now that we've trained both models, let's deploy to endpoints to serve inference and compare performance.
#
# ### U-Net Endpoint

# %%
unet_endpoint = 'cubicasa5k-unet-endpoint-' + \
    time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())

unet_predictor = unet_single_machine_estimator.deploy(instance_type='ml.c5.xlarge', initial_instance_count=1,
                                                      endpoint_name=unet_endpoint)
# Out:
# Using already existing model: cubicasa-unet-single-machine-job-2020-0-2020-03-30-06-02-45-296
# -----------!

# %% [markdown]
# Let's get a test response.

# %%
response = unet_predictor.predict(test_brain.tolist())

# %% [markdown]
# Compare with input and ground truth.

# %%
output = np.argmax(np.array(response), axis=(1))[0].astype(np.uint8)
plt.figure(figsize=(14, 14))
plt.subplot(131)
plt.title('Input')
plt.imshow(test_brain[0][0], cmap=plt.cm.gray)
plt.subplot(132)
plt.title('Ground Truth')
plt.imshow(test_mask[0][0], cmap=plt.cm.gray)
plt.subplot(133)
plt.title('Prediction')
plt.imshow(output, cmap=plt.cm.gray)

# %% [markdown]
# ### ENet Endpoint

# %% [markdown]
# Now let's deploy our ENet model.
#
# Instead of using <tt>estimator</tt>'s <tt>deploy</tt> method, as an exercise we'll create a model object <tt>MXNetModel</tt> instead. We'll pass the location of the ENet model artifact from the training job; this is how you would "bring your own model" to SageMaker to deploy to an endpoint.

# %%
enet_endpoint = 'cubicasa5k-enet-endpoint-' + \
    time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())
enet_model = sagemaker.mxnet.MXNetModel(enet_single_machine_estimator.model_data, role, 'floorplan_segmentation.py',
                                        source_dir='source_dir', framework_version="1.0",py_version='py3')

enet_predictor = enet_model.deploy(instance_type='ml.c5.xlarge', initial_instance_count=1,endpoint_name=enet_endpoint)
# Out:
# ---------!

# %% [markdown]
# Let's get a test response.

# %%
response = enet_predictor.predict(test_brain.tolist())

# %% [markdown]
# Compare with input and ground truth.

# %%
output = np.argmax(np.array(response), axis=(1))[0].astype(np.uint8)
plt.figure(figsize=(14, 14))
plt.subplot(131)
plt.title('Input')
plt.imshow(test_brain[0][0], cmap=plt.cm.gray)
plt.subplot(132)
plt.title('Ground Truth')
plt.imshow(test_mask[0][0], cmap=plt.cm.gray)
plt.subplot(133)
plt.title('Prediction')
plt.imshow(output, cmap=plt.cm.gray)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a68d84786fc2> in <module>()
# ----> 1 output = np.argmax(np.array(response), axis=(1))[0].astype(np.uint8)
#       2 plt.figure(figsize=(14, 14))
#       3 plt.subplot(131)
#       4 plt.title('Input')
#       5 plt.imshow(test_brain[0][0], cmap=plt.cm.gray)
#
# NameError: name 'np' is not defined

# %% [markdown]
# Qualitatively, these results look good. Let's quantitate this performance.
#
# ## Model Evaluation
#
# We're going to simultaneously visualize and quantify model performance using confusion matrices. To do this, we'll use this function to plot the matrix:

# %%
from sklearn.metrics import confusion_matrix
import itertools


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
#Citations
#@article{scikit-learn,
# title={Scikit-learn: Machine Learning in {P}ython},
# author={Pedregosa, F. and Varoquaux, G. and Gramfort, A. and Michel, V.
#         and Thirion, B. and Grisel, O. and Blondel, M. and Prettenhofer, P.
#         and Weiss, R. and Dubourg, V. and Vanderplas, J. and Passos, A. and
#         Cournapeau, D. and Brucher, M. and Perrot, M. and Duchesnay, E.},
# journal={Journal of Machine Learning Research},
# volume={12},
# pages={2825--2830},
# year={2011}
#}

# %% [markdown]
# ### U-Net
#
# We'll get predictions from our validation images, and load validation ground truths into memory as well.

# %%
ground_truths = []
outputs = []
for validation_pair in validation_pairs:
    img = np.array(Image.open(os.path.join(validation_dir, validation_pair[0])))[
        np.newaxis, np.newaxis, :]
    response = unet_predictor.predict(img.tolist())
    outputs.append(np.argmax(np.array(response), axis=(1))[0].astype(np.uint8))
    ground_truths.append(
        np.array(Image.open(os.path.join(validation_dir, validation_pair[1]))))
ground_truths = np.concatenate(ground_truths)
outputs = np.concatenate(outputs)
ground_truths = ground_truths.flatten()
outputs = outputs.flatten()

# %% [markdown]
# Now, we can compare the predictions to the ground truth labels.

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(ground_truths, outputs)
np.set_printoptions(precision=2)
class_names = [0, 1, 2, 3]

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[1078244  150311]
#  [  81183 1618902]]
# Normalized confusion matrix
# [[0.88 0.12]
#  [0.05 0.95]]

# %% [markdown]
# ### ENet
#
# We'll get predictions from our validation images, and load validation ground truths into memory as well.

# %%
ground_truths = []
outputs = []
for validation_pair in validation_pairs:
    img = np.array(Image.open(os.path.join(validation_dir, validation_pair[0])))[np.newaxis, np.newaxis, :]
    response = enet_predictor.predict(img.tolist())
    outputs.append(np.argmax(np.array(response), axis=(1))[0].astype(np.uint8))
    ground_truths.append(np.array(Image.open(os.path.join(validation_dir, validation_pair[1]))))
ground_truths = np.concatenate(ground_truths)
outputs = np.concatenate(outputs)
ground_truths = ground_truths.flatten()
outputs = outputs.flatten()

# %% [markdown]
# Now, we can compare the predictions to the ground truth labels.

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(ground_truths, outputs)
np.set_printoptions(precision=2)
class_names = [0, 1, 2, 3]

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[1095743  132812]
#  [  81057 1619028]]
# Normalized confusion matrix
# [[0.89 0.11]
#  [0.05 0.95]]

# %% [markdown]
# **Note**: To avoid unnecessary usage, make sure to delete your endpoints.

# %%
unet_single_machine_estimator.delete_endpoint()
sagemaker_session.delete_endpoint(enet_model.endpoint_name)

# %% [markdown]
# ## Extensions
#
# ### Distributed Training
#
# The data that we've trained on is a very small subset of what's available at OASIS. When training at scale, it's often the case that distributed training is a more cost-effective approach to training your network than vertical scaling, both from a time and dollar cost perspective.
#
# Here we demonstrate how simple it is to launch a distributed training job on SageMaker:
#
# 1. The script we provide must support distributed training (looking back at the entry point, note the management of the key-value store that supports synchronous distributed training in a multi-device environment).
# 2. Set <tt>train_instance_count</tt> from one to many.
# 3. Shard training data across nodes.
#
# For the latter, we define a sharded S3 input by setting <tt>distribution</tt> to <tt>ShardedByS3Key</tt>. This option will attempt to evenly split the number of objects under the provided pre-fix across nodes (this implicitly means you need as many objects under the prefix as nodes). Had we kept this argument as <tt>FullyReplicated</tt>, each node would have copies of the entire data set.
#
# We've put two compressed data sets under this prefix.

# %%
distributed_train_s3 = sagemaker.s3_input(s3_data=os.path.join(
    data_bucket, "dist"), distribution='ShardedByS3Key')

# %% [markdown]
# Now we can launch a distributed training job.

# %%
unet_distributed_job = 'DEMO-unet-distributed-job-' + \
    time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())

unet_distributed_estimator = MXNet(entry_point='brain_segmentation.py',
                                   base_job_name=unet_distributed_job,
                                   source_dir='source_dir',
                                   role=role,
                                   train_instance_count=2,
                                   train_instance_type='ml.p3.2xlarge',
                                   hyperparameters={
                                       'epochs': 50,
                                       'learning_rate': 1E-3,
                                       'class_weights': [[1.35, 17.18,  8.29, 12.42]],
                                       'network': 'unet',
                                       'batch_size': 32,
                                   })

unet_distributed_estimator.fit({'train': distributed_train_s3,
                                'test': validation_s3})

# %% [markdown]
# This may or may not actually be faster than the single machine training at this scale, but at larger scale distributed training is key.

# %% [markdown]
# ### Endpoint Invocation w/ S3

# %% [markdown]
# MXNet SageMaker endpoints are by default set up to run inference on data sent via POST request, with the assumption that the data sent is in the format of the data the model is trained on. For computer vision models, this can be problematic due to the bandwidth limits on SageMaker requests.
#
# One workaround is to instead submit an S3 URI, have the endpoint download the model locally, transform, and put the resulting mask back to S3. In this approach, there is no limit to the size of the content transformed.
#
# Let's take a look at the entry point for this hosting script:

# %%
# !cat source_dir/brain_segmentation_s3_transform.py

# %% [markdown]
# Since we already have a trained model, we'll directly define the <tt>model</tt> object using <tt>MXNetModel</tt> w/ the S3 location of our model artifact from the earlier training job. This is how you would "bring your own model" to SageMaker to deploy to an endpoint.

# %%
unet_s3_endpoint = 'DEMO-unet-s3-endpoint-' + \
    time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())

unet_s3_model = sagemaker.mxnet.MXNetModel(unet_single_machine_estimator.model_data, role,
                                           entry_point="brain_segmentation_s3_transform.py", source_dir='source_dir')

unet_s3_predictor = unet_s3_model.deploy(instance_type='ml.c5.xlarge', initial_instance_count=1,
                                         endpoint_name=unet_s3_endpoint)

# %% [markdown]
# Let's upload our test image to S3:

# %%
s3 = boto3.client('s3')
test_bucket = "<YOUR-BUCKET-HERE>"
prefix = "test_img.png"
s3.upload_file(Filename=os.path.join(validation_dir, 'OAS1_0004_MR1_mpr_n4_anon_111_t88_26.png'),
               Bucket=test_bucket, Key=prefix)

# %% [markdown]
# The body of our request will be in JSON format, so we'll define a dict containing the relevant fields and invoke the endpoint:

# %%
request_body = json.dumps({"bucket": test_bucket, "prefix": prefix})

response = unet_s3_predictor.predict([request_body])

# %% [markdown]
# Now let's download the result:

# %%
s3.download_file(Bucket=response['bucket'],
                 Key=response['prefix'], Filename="result.png")

plt.figure(figsize=(14, 14))
plt.subplot(131)
plt.title('Input')
plt.imshow(test_brain[0][0], cmap=plt.cm.gray)
plt.subplot(132)
plt.title('Ground Truth')
plt.imshow(test_mask[0][0], cmap=plt.cm.gray)
plt.subplot(133)
plt.title('Prediction')
plt.imshow(np.array(Image.open("result.png")), cmap=plt.cm.gray)

# %% [markdown]
# Currently, the only MXNet binary available for RPI through AWS is version 0.11. There's no native support for this version through the sdk, so we're going to define an estimator as usual and then manually set the training image to a container with MXNet 0.11.

# %% [markdown]
# Once set, the model is fit as usual.

# %% [markdown]
# Once trained, take note of the model location. You'll use this artifact as an ML Resource for Greengrass deployment.

# %% [markdown]
# To deploy this artifact, follow the instructions in the accompanying blog post.
#
# ## Acknowledgements
#
# This work was made possible with data provided by Open Access Series of Imaging Studies (OASIS), OASIS-1, by Marcus et al, 2007, used under CC BY 4.0.
#
# Data were provided by OASIS:
# -	OASIS-3: Principal Investigators: T. Benzinger, D. Marcus, J. Morris; NIH P50AG00561, P30NS09857781, P01AG026276, P01AG003991, R01AG043434, UL1TR000448, R01EB009352. AV-45 doses were provided by Avid Radiopharmaceuticals, a wholly owned subsidiary of Eli Lilly.
# -	OASIS: Cross-Sectional: Principal Investigators: D. Marcus, R, Buckner, J, Csernansky J. Morris; P50 AG05681, P01 AG03991, P01 AG026276, R01 AG021910, P20 MH071616, U24 RR021382
# -	OASIS: Longitudinal: Principal Investigators: D. Marcus, R, Buckner, J. Csernansky, J. Morris; P50 AG05681, P01 AG03991, P01 AG026276, R01 AG021910, P20 MH071616, U24 RR021382
#
# ### Publications:
# -	Open Access Series of Imaging Studies (OASIS): Cross-Sectional MRI Data in Young, Middle Aged, Nondemented, and Demented Older Adults
# Marcus, DS, Wang, TH, Parker, J, Csernansky, JG, Morris, JC, Buckner, RL. Journal of Cognitive Neuroscience, 19, 1498-1507. doi: 10.1162/jocn.2007.19.9.1498
